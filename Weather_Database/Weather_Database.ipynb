# %%
# %matplotlib inline

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
#cities

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# set counters.
record_count = 1
set_count = 1

print("-----------------------------")
print("Beginning Dara Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city  in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found.")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Dara Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | poum
# Processing Record 4 of Set 1 | karratha
# Processing Record 5 of Set 1 | gaborone
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | torbay
# Processing Record 9 of Set 1 | ostrovnoy
# Processing Record 10 of Set 1 | shitanjing
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | chicama
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | mogadishu
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | bathsheba
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | sorland
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | majene
# Processing Record 27 of Set 1 | taolanaro
# City not found.
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | inhambane
# Processing Record 30 of Set 1 | faya
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | hami
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | severo-yeniseyskiy
# Processing Record 37 of Set 1 | ahipara
# Processing Record 38 of Set 1 | itarema
# Processing Record 39 of Set 1 | egvekinot
# Processing Record 40 of Set 1 | puga
# Processing Record 41 of Set 1 | necochea
# Processing Record 42 of Set 1 | broken hill
# Processing Record 43 of Set 1 | barentsburg
# City not found.
# Processing Record 44 of Set 1 | kholodnyy
# Processing Record 45 of Set 1 | lazaro cardenas
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | sabla
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | awbari
# Processing Record 2 of Set 2 | vredendal
# Processing Record 3 of Set 2 | evanston
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | kolokani
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | suluktu
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | amderma
# City not found.
# Processing Record 11 of Set 2 | coahuayana
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | nalut
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | mao
# Processing Record 17 of Set 2 | plougastel-daoulas
# Processing Record 18 of Set 2 | inirida
# Processing Record 19 of Set 2 | aklavik
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | vardo
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | baicheng
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | holiday
# Processing Record 28 of Set 2 | fonseca
# Processing Record 29 of Set 2 | taoudenni
# Processing Record 30 of Set 2 | samarai
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found.
# Processing Record 35 of Set 2 | kisanga
# Processing Record 36 of Set 2 | otjiwarongo
# Processing Record 37 of Set 2 | yar-sale
# Processing Record 38 of Set 2 | gumushane
# City not found.
# Processing Record 39 of Set 2 | mehamn
# Processing Record 40 of Set 2 | tungor
# Processing Record 41 of Set 2 | mambajao
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | brookhaven
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | jacqueville
# Processing Record 46 of Set 2 | khandagayty
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | san jose del golfo
# Processing Record 49 of Set 2 | fort nelson
# Processing Record 50 of Set 2 | bandarbeyla
# Processing Record 1 of Set 3 | san juan
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | norilsk
# Processing Record 5 of Set 3 | rio grande
# Processing Record 6 of Set 3 | maldonado
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | kpandae
# Processing Record 9 of Set 3 | boa vista
# Processing Record 10 of Set 3 | alugan
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | avon
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | attawapiskat
# City not found.
# Processing Record 16 of Set 3 | hambantota
# Processing Record 17 of Set 3 | pagudpud
# Processing Record 18 of Set 3 | qui nhon
# Processing Record 19 of Set 3 | hobyo
# Processing Record 20 of Set 3 | ituni
# City not found.
# Processing Record 21 of Set 3 | daru
# Processing Record 22 of Set 3 | moose factory
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | draguignan
# Processing Record 27 of Set 3 | kailua
# Processing Record 28 of Set 3 | north bend
# Processing Record 29 of Set 3 | naqadeh
# Processing Record 30 of Set 3 | yellandu
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | pontalina
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | tuatapere
# Processing Record 36 of Set 3 | rio gallegos
# Processing Record 37 of Set 3 | tateyama
# Processing Record 38 of Set 3 | sa kaeo
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | port hardy
# Processing Record 41 of Set 3 | ust-kuyga
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | lakota
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | kutum
# Processing Record 46 of Set 3 | saleaula
# City not found.
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found.
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | manjacaze
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | lewistown
# Processing Record 2 of Set 4 | pag
# Processing Record 3 of Set 4 | romny
# Processing Record 4 of Set 4 | yomitan
# City not found.
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | sadri
# Processing Record 7 of Set 4 | soledade
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | mackenzie
# Processing Record 10 of Set 4 | kizhinga
# Processing Record 11 of Set 4 | iqaluit
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | berlevag
# Processing Record 14 of Set 4 | atar
# Processing Record 15 of Set 4 | komsomolskiy
# Processing Record 16 of Set 4 | kokopo
# Processing Record 17 of Set 4 | ahuimanu
# Processing Record 18 of Set 4 | dehloran
# Processing Record 19 of Set 4 | jishou
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | douglas
# Processing Record 22 of Set 4 | yarmouth
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | xinzhou
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | puerto maldonado
# Processing Record 27 of Set 4 | tsihombe
# City not found.
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | warrnambool
# Processing Record 30 of Set 4 | haibowan
# City not found.
# Processing Record 31 of Set 4 | cagliari
# Processing Record 32 of Set 4 | vaitupu
# City not found.
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | beloha
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | irece
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | novyy urengoy
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | pitimbu
# Processing Record 41 of Set 4 | nome
# Processing Record 42 of Set 4 | saryshagan
# City not found.
# Processing Record 43 of Set 4 | westpunt
# City not found.
# Processing Record 44 of Set 4 | krasnovka
# Processing Record 45 of Set 4 | bethel
# Processing Record 46 of Set 4 | nizhneyansk
# City not found.
# Processing Record 47 of Set 4 | sembakung
# Processing Record 48 of Set 4 | palmer
# Processing Record 49 of Set 4 | boquira
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | dimitrovgrad
# Processing Record 2 of Set 5 | kerema
# Processing Record 3 of Set 5 | vestmannaeyjar
# Processing Record 4 of Set 5 | chutove
# Processing Record 5 of Set 5 | bitung
# Processing Record 6 of Set 5 | los llanos de aridane
# Processing Record 7 of Set 5 | bodden town
# Processing Record 8 of Set 5 | katobu
# Processing Record 9 of Set 5 | miyang
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | kapaa
# Processing Record 12 of Set 5 | itapaci
# Processing Record 13 of Set 5 | kodinsk
# Processing Record 14 of Set 5 | bengkulu
# Processing Record 15 of Set 5 | bukene
# Processing Record 16 of Set 5 | vallenar
# Processing Record 17 of Set 5 | kracheh
# City not found.
# Processing Record 18 of Set 5 | kongolo
# Processing Record 19 of Set 5 | mys shmidta
# City not found.
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | gamba
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | vila
# Processing Record 24 of Set 5 | nguru
# Processing Record 25 of Set 5 | banmo
# City not found.
# Processing Record 26 of Set 5 | chulman
# Processing Record 27 of Set 5 | khash
# Processing Record 28 of Set 5 | srandakan
# Processing Record 29 of Set 5 | sobolevo
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | fort frances
# Processing Record 32 of Set 5 | homer
# Processing Record 33 of Set 5 | artyom
# Processing Record 34 of Set 5 | ulaanbaatar
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | itoman
# Processing Record 37 of Set 5 | saint-philippe
# Processing Record 38 of Set 5 | zhitikara
# City not found.
# Processing Record 39 of Set 5 | wad rawah
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | azimur
# City not found.
# Processing Record 43 of Set 5 | winchester
# Processing Record 44 of Set 5 | pavino
# Processing Record 45 of Set 5 | paso de los toros
# Processing Record 46 of Set 5 | alpena
# Processing Record 47 of Set 5 | severnyy
# Processing Record 48 of Set 5 | qaanaaq
# Processing Record 49 of Set 5 | antofagasta
# Processing Record 50 of Set 5 | mitsamiouli
# Processing Record 1 of Set 6 | kenai
# Processing Record 2 of Set 6 | mullaitivu
# City not found.
# Processing Record 3 of Set 6 | chiredzi
# Processing Record 4 of Set 6 | nguiu
# City not found.
# Processing Record 5 of Set 6 | el wasta
# City not found.
# Processing Record 6 of Set 6 | turbat
# Processing Record 7 of Set 6 | suntar
# Processing Record 8 of Set 6 | sistranda
# Processing Record 9 of Set 6 | nakamura
# Processing Record 10 of Set 6 | baruun-urt
# Processing Record 11 of Set 6 | whitehorse
# Processing Record 12 of Set 6 | lata
# Processing Record 13 of Set 6 | la ronge
# Processing Record 14 of Set 6 | garden city
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | ushtobe
# Processing Record 17 of Set 6 | nouakchott
# Processing Record 18 of Set 6 | gwanda
# Processing Record 19 of Set 6 | porbandar
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | lyngseidet
# Processing Record 22 of Set 6 | amboasary
# Processing Record 23 of Set 6 | yarim
# Processing Record 24 of Set 6 | kamenskoye
# City not found.
# Processing Record 25 of Set 6 | gorontalo
# Processing Record 26 of Set 6 | ribeira grande
# Processing Record 27 of Set 6 | patea
# Processing Record 28 of Set 6 | smolyaninovo
# Processing Record 29 of Set 6 | dese
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | oranjemund
# Processing Record 32 of Set 6 | lahat
# Processing Record 33 of Set 6 | seoul
# Processing Record 34 of Set 6 | tolaga bay
# Processing Record 35 of Set 6 | coihaique
# Processing Record 36 of Set 6 | longyearbyen
# Processing Record 37 of Set 6 | jalu
# Processing Record 38 of Set 6 | malwan
# City not found.
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | riyadh
# Processing Record 41 of Set 6 | kawalu
# Processing Record 42 of Set 6 | batagay-alyta
# Processing Record 43 of Set 6 | olutanga
# Processing Record 44 of Set 6 | provideniya
# Processing Record 45 of Set 6 | catuday
# Processing Record 46 of Set 6 | matara
# Processing Record 47 of Set 6 | palmares do sul
# Processing Record 48 of Set 6 | medea
# Processing Record 49 of Set 6 | ballina
# Processing Record 50 of Set 6 | acolla
# Processing Record 1 of Set 7 | muli
# Processing Record 2 of Set 7 | aguimes
# Processing Record 3 of Set 7 | lavrentiya
# Processing Record 4 of Set 7 | korla
# Processing Record 5 of Set 7 | merauke
# Processing Record 6 of Set 7 | palabuhanratu
# City not found.
# Processing Record 7 of Set 7 | bundaberg
# Processing Record 8 of Set 7 | burgeo
# Processing Record 9 of Set 7 | fonte boa
# Processing Record 10 of Set 7 | sur
# Processing Record 11 of Set 7 | koumac
# Processing Record 12 of Set 7 | port macquarie
# Processing Record 13 of Set 7 | dhidhdhoo
# Processing Record 14 of Set 7 | port maria
# Processing Record 15 of Set 7 | kamaishi
# Processing Record 16 of Set 7 | kidal
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | sangar
# Processing Record 19 of Set 7 | hualmay
# Processing Record 20 of Set 7 | aksarayskiy
# Processing Record 21 of Set 7 | zhangzhou
# Processing Record 22 of Set 7 | sibolga
# Processing Record 23 of Set 7 | aguadilla
# Processing Record 24 of Set 7 | sorvag
# City not found.
# Processing Record 25 of Set 7 | sechura
# Processing Record 26 of Set 7 | kandrian
# Processing Record 27 of Set 7 | teneguiban
# City not found.
# Processing Record 28 of Set 7 | harindanga
# Processing Record 29 of Set 7 | pevek
# Processing Record 30 of Set 7 | yaguara
# Processing Record 31 of Set 7 | belmonte
# Processing Record 32 of Set 7 | jiangyou
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | hovd
# Processing Record 35 of Set 7 | visnes
# Processing Record 36 of Set 7 | bowen
# Processing Record 37 of Set 7 | nagram
# Processing Record 38 of Set 7 | bo
# City not found.
# Processing Record 39 of Set 7 | saint-pierre
# Processing Record 40 of Set 7 | airai
# Processing Record 41 of Set 7 | chase
# Processing Record 42 of Set 7 | san cristobal
# Processing Record 43 of Set 7 | leningradskiy
# Processing Record 44 of Set 7 | lorengau
# Processing Record 45 of Set 7 | makung
# City not found.
# Processing Record 46 of Set 7 | sibu
# Processing Record 47 of Set 7 | grand river south east
# City not found.
# Processing Record 48 of Set 7 | mushie
# Processing Record 49 of Set 7 | saint anthony
# Processing Record 50 of Set 7 | prieska
# Processing Record 1 of Set 8 | shubarshi
# Processing Record 2 of Set 8 | pozzallo
# Processing Record 3 of Set 8 | sitka
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | kalvarija
# Processing Record 7 of Set 8 | azoyu
# Processing Record 8 of Set 8 | hillsboro
# Processing Record 9 of Set 8 | clinton
# Processing Record 10 of Set 8 | gayny
# Processing Record 11 of Set 8 | muzhi
# Processing Record 12 of Set 8 | axim
# Processing Record 13 of Set 8 | corlu
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | acara
# Processing Record 16 of Set 8 | vilya
# Processing Record 17 of Set 8 | aland
# Processing Record 18 of Set 8 | aguie
# Processing Record 19 of Set 8 | buchanan
# Processing Record 20 of Set 8 | isiro
# Processing Record 21 of Set 8 | jiuquan
# Processing Record 22 of Set 8 | maroua
# Processing Record 23 of Set 8 | nadym
# Processing Record 24 of Set 8 | bridlington
# Processing Record 25 of Set 8 | half moon bay
# Processing Record 26 of Set 8 | samusu
# City not found.
# Processing Record 27 of Set 8 | panaba
# Processing Record 28 of Set 8 | mpongwe
# Processing Record 29 of Set 8 | birao
# Processing Record 30 of Set 8 | mareeba
# Processing Record 31 of Set 8 | ambilobe
# Processing Record 32 of Set 8 | ashtabula
# Processing Record 33 of Set 8 | yining
# Processing Record 34 of Set 8 | kingaroy
# Processing Record 35 of Set 8 | abha
# Processing Record 36 of Set 8 | kualakapuas
# Processing Record 37 of Set 8 | santa marta
# Processing Record 38 of Set 8 | darhan
# Processing Record 39 of Set 8 | belushya guba
# City not found.
# Processing Record 40 of Set 8 | ibra
# Processing Record 41 of Set 8 | runcu
# Processing Record 42 of Set 8 | dwarahat
# Processing Record 43 of Set 8 | mount gambier
# Processing Record 44 of Set 8 | puerto cabezas
# Processing Record 45 of Set 8 | puerto carreno
# Processing Record 46 of Set 8 | humboldt
# Processing Record 47 of Set 8 | baft
# Processing Record 48 of Set 8 | kalmunai
# Processing Record 49 of Set 8 | zhuhai
# Processing Record 50 of Set 8 | makubetsu
# Processing Record 1 of Set 9 | grand centre
# City not found.
# Processing Record 2 of Set 9 | ozark
# Processing Record 3 of Set 9 | gazanjyk
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 5 of Set 9 | namatanai
# Processing Record 6 of Set 9 | honningsvag
# Processing Record 7 of Set 9 | simao
# Processing Record 8 of Set 9 | cayenne
# Processing Record 9 of Set 9 | owando
# Processing Record 10 of Set 9 | zapolyarnyy
# Processing Record 11 of Set 9 | biak
# Processing Record 12 of Set 9 | bossangoa
# Processing Record 13 of Set 9 | havre-saint-pierre
# Processing Record 14 of Set 9 | bukachacha
# Processing Record 15 of Set 9 | isangel
# Processing Record 16 of Set 9 | kroya
# Processing Record 17 of Set 9 | sun city
# Processing Record 18 of Set 9 | najran
# Processing Record 19 of Set 9 | bjerkvik
# Processing Record 20 of Set 9 | okhotsk
# Processing Record 21 of Set 9 | batagay
# Processing Record 22 of Set 9 | zhigansk
# Processing Record 23 of Set 9 | black forest
# Processing Record 24 of Set 9 | bissora
# Processing Record 25 of Set 9 | clive
# Processing Record 26 of Set 9 | san patricio
# Processing Record 27 of Set 9 | pangai
# Processing Record 28 of Set 9 | manta
# Processing Record 29 of Set 9 | satitoa
# City not found.
# Processing Record 30 of Set 9 | zvishavane
# Processing Record 31 of Set 9 | meyungs
# City not found.
# Processing Record 32 of Set 9 | guerrero
# Processing Record 33 of Set 9 | cumbitara
# Processing Record 34 of Set 9 | pauini
# Processing Record 35 of Set 9 | donnacona
# Processing Record 36 of Set 9 | oudtshoorn
# Processing Record 37 of Set 9 | coruripe
# Processing Record 38 of Set 9 | baykit
# Processing Record 39 of Set 9 | inderborskiy
# City not found.
# Processing Record 40 of Set 9 | saint george
# Processing Record 41 of Set 9 | penalva
# Processing Record 42 of Set 9 | mount isa
# Processing Record 43 of Set 9 | naberera
# Processing Record 44 of Set 9 | burnie
# Processing Record 45 of Set 9 | san vicente
# Processing Record 46 of Set 9 | hamilton
# Processing Record 47 of Set 9 | gao
# Processing Record 48 of Set 9 | tadine
# Processing Record 49 of Set 9 | sorong
# Processing Record 50 of Set 9 | alta floresta
# Processing Record 1 of Set 10 | sakakah
# Processing Record 2 of Set 10 | ca mau
# Processing Record 3 of Set 10 | machali
# Processing Record 4 of Set 10 | porto novo
# Processing Record 5 of Set 10 | galle
# Processing Record 6 of Set 10 | ust-tsilma
# Processing Record 7 of Set 10 | metro
# Processing Record 8 of Set 10 | falealupo
# City not found.
# Processing Record 9 of Set 10 | matagami
# Processing Record 10 of Set 10 | loveland
# Processing Record 11 of Set 10 | payo
# Processing Record 12 of Set 10 | nuuk
# Processing Record 13 of Set 10 | montrose
# Processing Record 14 of Set 10 | marcona
# City not found.
# Processing Record 15 of Set 10 | fevralsk
# City not found.
# Processing Record 16 of Set 10 | nioro
# Processing Record 17 of Set 10 | helsinki
# Processing Record 18 of Set 10 | palm coast
# Processing Record 19 of Set 10 | pinawa
# Processing Record 20 of Set 10 | bubaque
# Processing Record 21 of Set 10 | aquidauana
# Processing Record 22 of Set 10 | kamina
# Processing Record 23 of Set 10 | neuquen
# Processing Record 24 of Set 10 | inayagan
# Processing Record 25 of Set 10 | paamiut
# Processing Record 26 of Set 10 | santa isabel
# Processing Record 27 of Set 10 | fare
# Processing Record 28 of Set 10 | portland
# Processing Record 29 of Set 10 | osmena
# Processing Record 30 of Set 10 | puyang
# Processing Record 31 of Set 10 | zayukovo
# Processing Record 32 of Set 10 | eureka
# Processing Record 33 of Set 10 | pangnirtung
# Processing Record 34 of Set 10 | santander
# Processing Record 35 of Set 10 | ozinki
# Processing Record 36 of Set 10 | akyab
# Processing Record 37 of Set 10 | clyde river
# Processing Record 38 of Set 10 | estreito
# Processing Record 39 of Set 10 | katsina
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | eastbourne
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | nkhotakota
# Processing Record 44 of Set 10 | dzhusaly
# City not found.
# Processing Record 45 of Set 10 | louisbourg
# City not found.
# Processing Record 46 of Set 10 | evensk
# Processing Record 47 of Set 10 | tchamba
# Processing Record 48 of Set 10 | envira
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | constantine
# Processing Record 1 of Set 11 | kamien pomorski
# Processing Record 2 of Set 11 | berdyuzhye
# City not found.
# Processing Record 3 of Set 11 | kharan
# Processing Record 4 of Set 11 | marolambo
# Processing Record 5 of Set 11 | marzuq
# Processing Record 6 of Set 11 | narsaq
# Processing Record 7 of Set 11 | ust-ilimsk
# Processing Record 8 of Set 11 | sumbe
# Processing Record 9 of Set 11 | yabelo
# Processing Record 10 of Set 11 | hailey
# Processing Record 11 of Set 11 | valavanur
# Processing Record 12 of Set 11 | valparaiso
# Processing Record 13 of Set 11 | jutai
# Processing Record 14 of Set 11 | xiaoweizhai
# Processing Record 15 of Set 11 | cassano delle murge
# Processing Record 16 of Set 11 | caravelas
# Processing Record 17 of Set 11 | cuamba
# Processing Record 18 of Set 11 | filingue
# Processing Record 19 of Set 11 | cradock
# Processing Record 20 of Set 11 | yertsevo
# Processing Record 21 of Set 11 | shizuishan
# Processing Record 22 of Set 11 | deputatskiy
# Processing Record 23 of Set 11 | kirakira
# Processing Record 24 of Set 11 | san luis
# Processing Record 25 of Set 11 | abonnema
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | shingu
# Processing Record 28 of Set 11 | nanortalik
# Processing Record 29 of Set 11 | taltal
# Processing Record 30 of Set 11 | bom jesus
# Processing Record 31 of Set 11 | mopti
# Processing Record 32 of Set 11 | hoima
# Processing Record 33 of Set 11 | vostok
# Processing Record 34 of Set 11 | akhmeta
# Processing Record 35 of Set 11 | yaan
# Processing Record 36 of Set 11 | ukiah
# Processing Record 37 of Set 11 | raipur
# Processing Record 38 of Set 11 | zambezi
# Processing Record 39 of Set 11 | gejiu
# Processing Record 40 of Set 11 | caxito
# Processing Record 41 of Set 11 | ondorhaan
# City not found.
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | betafo
# Processing Record 44 of Set 11 | batouri
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | goryachegorsk
# Processing Record 47 of Set 11 | manokwari
# Processing Record 48 of Set 11 | brae
# Processing Record 49 of Set 11 | ekhabi
# Processing Record 50 of Set 11 | vila franca do campo
# Processing Record 1 of Set 12 | oriximina
# Processing Record 2 of Set 12 | chateau-thierry
# Processing Record 3 of Set 12 | gravdal
# Processing Record 4 of Set 12 | jiaozuo
# Processing Record 5 of Set 12 | pangody
# Processing Record 6 of Set 12 | vao
# Processing Record 7 of Set 12 | wilmington
# Processing Record 8 of Set 12 | beringovskiy
# Processing Record 9 of Set 12 | springdale
# Processing Record 10 of Set 12 | dong hoi
# Processing Record 11 of Set 12 | maua
# Processing Record 12 of Set 12 | kushiro
# Processing Record 13 of Set 12 | malabor
# Processing Record 14 of Set 12 | hofn
# Processing Record 15 of Set 12 | spencer
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | ciudad bolivar
# Processing Record 18 of Set 12 | barbar
# City not found.
# Processing Record 19 of Set 12 | black river
# Processing Record 20 of Set 12 | razole
# Processing Record 21 of Set 12 | svetlogorsk
# Processing Record 22 of Set 12 | sinnamary
# Processing Record 23 of Set 12 | bograd
# Processing Record 24 of Set 12 | sedelnikovo
# City not found.
# Processing Record 25 of Set 12 | sujawal
# City not found.
# Processing Record 26 of Set 12 | odessa
# Processing Record 27 of Set 12 | belokurikha
# Processing Record 28 of Set 12 | yulara
# Processing Record 29 of Set 12 | huarmey
# Processing Record 30 of Set 12 | charleston
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | voloshka
# Processing Record 33 of Set 12 | vetlanda
# Processing Record 34 of Set 12 | morwell
# Processing Record 35 of Set 12 | sao felix do xingu
# Processing Record 36 of Set 12 | sataua
# City not found.
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | yelizovo
# Processing Record 39 of Set 12 | berdigestyakh
# Processing Record 40 of Set 12 | namibe
# Processing Record 41 of Set 12 | camacha
# Processing Record 42 of Set 12 | pacific grove
# Processing Record 43 of Set 12 | tukrah
# Processing Record 44 of Set 12 | panzhihua
# Processing Record 45 of Set 12 | ulaangom
# Processing Record 46 of Set 12 | pandamatenga
# Processing Record 47 of Set 12 | taicheng
# Processing Record 48 of Set 12 | mosterhamn
# Processing Record 49 of Set 12 | bolungarvik
# City not found.
# Processing Record 50 of Set 12 | luwuk
# Processing Record 1 of Set 13 | kashima
# Processing Record 2 of Set 13 | batemans bay
# Processing Record 3 of Set 13 | ranong
# Processing Record 4 of Set 13 | ketchikan
# Processing Record 5 of Set 13 | baijiantan
# Processing Record 6 of Set 13 | mirandela
# Processing Record 7 of Set 13 | kitob
# Processing Record 8 of Set 13 | nelson bay
# Processing Record 9 of Set 13 | yenagoa
# Processing Record 10 of Set 13 | gollere
# City not found.
# Processing Record 11 of Set 13 | carnot
# Processing Record 12 of Set 13 | henties bay
# Processing Record 13 of Set 13 | burica
# City not found.
# Processing Record 14 of Set 13 | jacareacanga
# Processing Record 15 of Set 13 | kropotkin
# Processing Record 16 of Set 13 | togur
# Processing Record 17 of Set 13 | marrakesh
# Processing Record 18 of Set 13 | dillon
# Processing Record 19 of Set 13 | aras
# Processing Record 20 of Set 13 | alice springs
# Processing Record 21 of Set 13 | la ligua
# Processing Record 22 of Set 13 | praia
# Processing Record 23 of Set 13 | rawannawi
# City not found.
# Processing Record 24 of Set 13 | masvingo
# Processing Record 25 of Set 13 | petropavlovka
# Processing Record 26 of Set 13 | kestel
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | fukue
# Processing Record 29 of Set 13 | bosobolo
# Processing Record 30 of Set 13 | talnakh
# Processing Record 31 of Set 13 | clarence town
# Processing Record 32 of Set 13 | sisimiut
# Processing Record 33 of Set 13 | veraval
# Processing Record 34 of Set 13 | kuraymah
# Processing Record 35 of Set 13 | kasane
# Processing Record 36 of Set 13 | kilrush
# Processing Record 37 of Set 13 | natal
# Processing Record 38 of Set 13 | san andres
# Processing Record 39 of Set 13 | yozgat
# Processing Record 40 of Set 13 | mahon
# Processing Record 41 of Set 13 | luba
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | mutsamudu
# City not found.
# Processing Record 44 of Set 13 | menongue
# Processing Record 45 of Set 13 | salinopolis
# Processing Record 46 of Set 13 | gallup
# Processing Record 47 of Set 13 | tautira
# Processing Record 48 of Set 13 | zelenets
# Processing Record 49 of Set 13 | trat
# Processing Record 50 of Set 13 | lasa
# Processing Record 1 of Set 14 | achisay
# City not found.
# Processing Record 2 of Set 14 | toora-khem
# Processing Record 3 of Set 14 | rizhao
# Processing Record 4 of Set 14 | santa maria
# Processing Record 5 of Set 14 | felidhoo
# City not found.
# Processing Record 6 of Set 14 | kismayo
# Processing Record 7 of Set 14 | saint-francois
# Processing Record 8 of Set 14 | gamboula
# Processing Record 9 of Set 14 | karpogory
# Processing Record 10 of Set 14 | viligili
# City not found.
# Processing Record 11 of Set 14 | anadyr
# Processing Record 12 of Set 14 | zakamensk
# Processing Record 13 of Set 14 | bintulu
# Processing Record 14 of Set 14 | sioux lookout
# Processing Record 15 of Set 14 | luanda
# Processing Record 16 of Set 14 | shenjiamen
# Processing Record 17 of Set 14 | comodoro rivadavia
# Processing Record 18 of Set 14 | amnat charoen
# Processing Record 19 of Set 14 | pacifica
# Processing Record 20 of Set 14 | pudozh
# Processing Record 21 of Set 14 | nyurba
# Processing Record 22 of Set 14 | biu
# Processing Record 23 of Set 14 | luorong
# Processing Record 24 of Set 14 | kuytun
# Processing Record 25 of Set 14 | salalah
# Processing Record 26 of Set 14 | sabang
# Processing Record 27 of Set 14 | balaipungut
# Processing Record 28 of Set 14 | noshiro
# Processing Record 29 of Set 14 | yacuiba
# Processing Record 30 of Set 14 | hienghene
# Processing Record 31 of Set 14 | tahta
# Processing Record 32 of Set 14 | bad harzburg
# Processing Record 33 of Set 14 | tenneville
# Processing Record 34 of Set 14 | novo aripuana
# Processing Record 35 of Set 14 | langxiang
# Processing Record 36 of Set 14 | semey
# Processing Record 37 of Set 14 | monroe
# Processing Record 38 of Set 14 | suileng
# Processing Record 39 of Set 14 | te anau
# Processing Record 40 of Set 14 | tumannyy
# City not found.
# Processing Record 41 of Set 14 | sindand
# City not found.
# Processing Record 42 of Set 14 | siniscola
# Processing Record 43 of Set 14 | birjand
# Processing Record 44 of Set 14 | kajaani
# Processing Record 45 of Set 14 | oranjestad
# Processing Record 46 of Set 14 | mawlaik
# Processing Record 47 of Set 14 | qaracala
# Processing Record 48 of Set 14 | san joaquin
# Processing Record 49 of Set 14 | ati
# Processing Record 50 of Set 14 | tual
# Processing Record 1 of Set 15 | jaisalmer
# Processing Record 2 of Set 15 | moldova noua
# Processing Record 3 of Set 15 | puerto colombia
# Processing Record 4 of Set 15 | souillac
# Processing Record 5 of Set 15 | monchique
# Processing Record 6 of Set 15 | zeerust
# Processing Record 7 of Set 15 | laurel
# Processing Record 8 of Set 15 | asfi
# Processing Record 9 of Set 15 | tunxi
# City not found.
# Processing Record 10 of Set 15 | flagstaff
# Processing Record 11 of Set 15 | savelugu
# Processing Record 12 of Set 15 | cordoba
# Processing Record 13 of Set 15 | nemuro
# Processing Record 14 of Set 15 | chapada dos guimaraes
# Processing Record 15 of Set 15 | makakilo city
# Processing Record 16 of Set 15 | asau
# Processing Record 17 of Set 15 | jibuti
# Processing Record 18 of Set 15 | qingdao
# Processing Record 19 of Set 15 | bac lieu
# Processing Record 20 of Set 15 | takoradi
# Processing Record 21 of Set 15 | baracoa
# Processing Record 22 of Set 15 | amapa
# Processing Record 23 of Set 15 | parli
# Processing Record 24 of Set 15 | ninh binh
# Processing Record 25 of Set 15 | quime
# Processing Record 26 of Set 15 | lexington
# Processing Record 27 of Set 15 | gwadar
# Processing Record 28 of Set 15 | mosquera
# Processing Record 29 of Set 15 | bilibino
# Processing Record 30 of Set 15 | solton
# Processing Record 31 of Set 15 | tabas
# Processing Record 32 of Set 15 | marsh harbour
# Processing Record 33 of Set 15 | bayan
# Processing Record 34 of Set 15 | arman
# Processing Record 35 of Set 15 | pathein
# Processing Record 36 of Set 15 | zyryanka
# Processing Record 37 of Set 15 | nabinagar
# Processing Record 38 of Set 15 | marawi
# Processing Record 39 of Set 15 | san policarpo
# Processing Record 40 of Set 15 | impfondo
# Processing Record 41 of Set 15 | chapais
# Processing Record 42 of Set 15 | bajram curri
# Processing Record 43 of Set 15 | gardez
# Processing Record 44 of Set 15 | chatra
# Processing Record 45 of Set 15 | nazarovo
# Processing Record 46 of Set 15 | uray
# Processing Record 47 of Set 15 | lamu
# Processing Record 48 of Set 15 | dingle
# Processing Record 49 of Set 15 | boyabat
# Processing Record 50 of Set 15 | konigslutter
# City not found.
# Processing Record 1 of Set 16 | nagato
# Processing Record 2 of Set 16 | mayumba
# Processing Record 3 of Set 16 | tiassale
# Processing Record 4 of Set 16 | ferme-neuve
# Processing Record 5 of Set 16 | masakin
# Processing Record 6 of Set 16 | joao pinheiro
# Processing Record 7 of Set 16 | laiyang
# Processing Record 8 of Set 16 | pierre
# Processing Record 9 of Set 16 | port augusta
# Processing Record 10 of Set 16 | srednekolymsk
# Processing Record 11 of Set 16 | maragogi
# Processing Record 12 of Set 16 | shaunavon
# Processing Record 13 of Set 16 | laon
# Processing Record 14 of Set 16 | dunedin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     74.50        58          62
# 1        Buraydah      SA  26.3260   43.9750     39.65        33           0
# 2            Poum      NC -20.2333  164.0167     83.05        76          98
# 3        Karratha      AU -20.7377  116.8463     98.11        35          64
# 4        Gaborone      BW -24.6545   25.9086     62.51        77           0
# 5           Vaini      TO -21.2000 -175.2000     86.16        74          40
# 6     Tuktoyaktuk      CA  69.4541 -133.0374    -31.00        75          75
# 7          Torbay      CA  47.6666  -52.7314     32.76        87         100
# 8       Ostrovnoy      RU  68.0531   39.5131     21.24        83         100
# 9      Shitanjing      CN  39.2342  106.3439     20.03        49         100
#
#    Wind Speed Current Description
# 0        7.16       broken clouds
# 1        4.00           clear sky
# 2       11.30     overcast clouds
# 3        9.75       broken clouds
# 4        3.44           clear sky
# 5        8.05    scattered clouds
# 6        9.22       broken clouds
# 7       10.36     overcast clouds
# 8       26.93     overcast clouds
# 9        2.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
