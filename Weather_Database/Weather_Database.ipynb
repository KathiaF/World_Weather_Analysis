# %%
# %matplotlib inline

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 716

# %%
#cities

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# set counters.
record_count = 1
set_count = 1

print("-----------------------------")
print("Beginning Dara Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city  in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found.")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Dara Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chokurdakh
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | port hedland
# Processing Record 6 of Set 1 | kidal
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | great falls
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | goundam
# Processing Record 16 of Set 1 | parsons
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | lapithos
# Processing Record 20 of Set 1 | kholmogory
# Processing Record 21 of Set 1 | ransang
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | attawapiskat
# City not found.
# Processing Record 25 of Set 1 | zeya
# Processing Record 26 of Set 1 | road town
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | tocopilla
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | formosa do rio preto
# Processing Record 32 of Set 1 | suez
# Processing Record 33 of Set 1 | taolanaro
# City not found.
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | ames
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | inhambane
# Processing Record 41 of Set 1 | kyren
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | havoysund
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | am timan
# Processing Record 1 of Set 2 | huazolotitlan
# City not found.
# Processing Record 2 of Set 2 | hunza
# City not found.
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | high level
# Processing Record 6 of Set 2 | nhulunbuy
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | mulchen
# Processing Record 9 of Set 2 | pacifica
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | sao joao da barra
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | wapakoneta
# Processing Record 14 of Set 2 | taoudenni
# Processing Record 15 of Set 2 | kitakami
# Processing Record 16 of Set 2 | hay river
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | yar-sale
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | plomarion
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | khandbari
# Processing Record 25 of Set 2 | tecoanapa
# Processing Record 26 of Set 2 | sorvag
# City not found.
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | the pas
# Processing Record 29 of Set 2 | nome
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | nisia floresta
# Processing Record 33 of Set 2 | saint-augustin
# Processing Record 34 of Set 2 | belushya guba
# City not found.
# Processing Record 35 of Set 2 | buchanan
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | ayagoz
# Processing Record 38 of Set 2 | amapa
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | raga
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | igrim
# Processing Record 45 of Set 2 | aklavik
# Processing Record 46 of Set 2 | knysna
# Processing Record 47 of Set 2 | rabat
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found.
# Processing Record 49 of Set 2 | tautira
# Processing Record 50 of Set 2 | walvis bay
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | turayf
# Processing Record 4 of Set 3 | sokoni
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | lemoore
# Processing Record 9 of Set 3 | tucuman
# Processing Record 10 of Set 3 | oranjestad
# Processing Record 11 of Set 3 | nizhneyansk
# City not found.
# Processing Record 12 of Set 3 | ampanihy
# Processing Record 13 of Set 3 | ust-tsilma
# Processing Record 14 of Set 3 | lucapa
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | kadarkut
# Processing Record 18 of Set 3 | ornskoldsvik
# Processing Record 19 of Set 3 | thisted
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | skagen
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | hualmay
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | linguere
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | saint-louis
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | umm kaddadah
# Processing Record 31 of Set 3 | sarlat-la-caneda
# Processing Record 32 of Set 3 | lebanon
# Processing Record 33 of Set 3 | sao felix do xingu
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | temaraia
# City not found.
# Processing Record 38 of Set 3 | mao
# Processing Record 39 of Set 3 | tromso
# Processing Record 40 of Set 3 | byron bay
# Processing Record 41 of Set 3 | hofn
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | ossora
# Processing Record 44 of Set 3 | tumannyy
# City not found.
# Processing Record 45 of Set 3 | muslyumovo
# Processing Record 46 of Set 3 | mushie
# Processing Record 47 of Set 3 | cahors
# Processing Record 48 of Set 3 | batticaloa
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | fukue
# Processing Record 1 of Set 4 | busselton
# Processing Record 2 of Set 4 | male
# Processing Record 3 of Set 4 | dvinskoy
# Processing Record 4 of Set 4 | yunjinghong
# City not found.
# Processing Record 5 of Set 4 | luanda
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | siguiri
# Processing Record 8 of Set 4 | monrovia
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | neiafu
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | mandalgovi
# Processing Record 14 of Set 4 | sambava
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | pangkalanbuun
# Processing Record 17 of Set 4 | filingue
# Processing Record 18 of Set 4 | kulunda
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | hobart
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | west wendover
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | leua
# Processing Record 25 of Set 4 | howard springs
# Processing Record 26 of Set 4 | tura
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | eldikan
# City not found.
# Processing Record 29 of Set 4 | ambositra
# Processing Record 30 of Set 4 | codrington
# Processing Record 31 of Set 4 | san quintin
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | wilmington
# Processing Record 34 of Set 4 | mys shmidta
# City not found.
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | lompoc
# Processing Record 37 of Set 4 | turukhansk
# Processing Record 38 of Set 4 | bereda
# Processing Record 39 of Set 4 | mayfield
# Processing Record 40 of Set 4 | vostok
# Processing Record 41 of Set 4 | nizhniy odes
# Processing Record 42 of Set 4 | saint-prosper
# Processing Record 43 of Set 4 | atocha
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | egvekinot
# Processing Record 46 of Set 4 | komsomolskiy
# Processing Record 47 of Set 4 | juneau
# Processing Record 48 of Set 4 | pimentel
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | boca do acre
# Processing Record 1 of Set 5 | saint anthony
# Processing Record 2 of Set 5 | saleaula
# City not found.
# Processing Record 3 of Set 5 | verkhoyansk
# Processing Record 4 of Set 5 | solnechnyy
# Processing Record 5 of Set 5 | shache
# Processing Record 6 of Set 5 | samalaeulu
# City not found.
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | umm lajj
# Processing Record 9 of Set 5 | dikson
# Processing Record 10 of Set 5 | robertsport
# Processing Record 11 of Set 5 | kushima
# Processing Record 12 of Set 5 | tukrah
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | sakakah
# Processing Record 15 of Set 5 | mokolo
# Processing Record 16 of Set 5 | gorno-chuyskiy
# City not found.
# Processing Record 17 of Set 5 | vila velha
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | qeshm
# Processing Record 20 of Set 5 | we
# City not found.
# Processing Record 21 of Set 5 | tsihombe
# City not found.
# Processing Record 22 of Set 5 | naifaru
# Processing Record 23 of Set 5 | orotukan
# Processing Record 24 of Set 5 | lagoa
# Processing Record 25 of Set 5 | deputatskiy
# Processing Record 26 of Set 5 | abu dhabi
# Processing Record 27 of Set 5 | victoria
# Processing Record 28 of Set 5 | rabaul
# Processing Record 29 of Set 5 | tumut
# Processing Record 30 of Set 5 | avera
# Processing Record 31 of Set 5 | lisieux
# Processing Record 32 of Set 5 | hirara
# Processing Record 33 of Set 5 | keokuk
# Processing Record 34 of Set 5 | chuy
# Processing Record 35 of Set 5 | amderma
# City not found.
# Processing Record 36 of Set 5 | razole
# Processing Record 37 of Set 5 | maroantsetra
# Processing Record 38 of Set 5 | sobolevo
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | barentsburg
# City not found.
# Processing Record 41 of Set 5 | sal rei
# Processing Record 42 of Set 5 | panguna
# Processing Record 43 of Set 5 | payo
# Processing Record 44 of Set 5 | nabire
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | camapua
# Processing Record 47 of Set 5 | quang ngai
# Processing Record 48 of Set 5 | aswan
# Processing Record 49 of Set 5 | amparai
# City not found.
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | kathu
# Processing Record 2 of Set 6 | guekedou
# City not found.
# Processing Record 3 of Set 6 | cherskiy
# Processing Record 4 of Set 6 | rorvik
# Processing Record 5 of Set 6 | torbay
# Processing Record 6 of Set 6 | paita
# Processing Record 7 of Set 6 | bend
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | gornopravdinsk
# Processing Record 10 of Set 6 | nantucket
# Processing Record 11 of Set 6 | udachnyy
# Processing Record 12 of Set 6 | beira
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | misratah
# Processing Record 15 of Set 6 | cap malheureux
# Processing Record 16 of Set 6 | yellamanchili
# City not found.
# Processing Record 17 of Set 6 | korla
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | duz
# City not found.
# Processing Record 22 of Set 6 | ustynivka
# Processing Record 23 of Set 6 | karkaralinsk
# City not found.
# Processing Record 24 of Set 6 | pauini
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | grand gaube
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | nouakchott
# Processing Record 29 of Set 6 | jega
# Processing Record 30 of Set 6 | boguchany
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | lamar
# Processing Record 33 of Set 6 | barranca
# Processing Record 34 of Set 6 | mosquera
# Processing Record 35 of Set 6 | neryungri
# Processing Record 36 of Set 6 | sikandarabad
# Processing Record 37 of Set 6 | maykain
# City not found.
# Processing Record 38 of Set 6 | samusu
# City not found.
# Processing Record 39 of Set 6 | kerman
# Processing Record 40 of Set 6 | grootfontein
# Processing Record 41 of Set 6 | kant
# Processing Record 42 of Set 6 | bafoulabe
# Processing Record 43 of Set 6 | magadan
# Processing Record 44 of Set 6 | grand-lahou
# Processing Record 45 of Set 6 | marseille
# Processing Record 46 of Set 6 | broken hill
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | banda aceh
# Processing Record 49 of Set 6 | wawa
# Processing Record 50 of Set 6 | yermakovskoye
# Processing Record 1 of Set 7 | carutapera
# Processing Record 2 of Set 7 | san-pedro
# Processing Record 3 of Set 7 | sydney
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | shelburne
# Processing Record 7 of Set 7 | ahipara
# Processing Record 8 of Set 7 | khairpur nathan shah
# Processing Record 9 of Set 7 | dzhebariki-khaya
# Processing Record 10 of Set 7 | honiara
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | airai
# Processing Record 13 of Set 7 | maple creek
# Processing Record 14 of Set 7 | viedma
# Processing Record 15 of Set 7 | kendari
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | uvarovka
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | sulam
# Processing Record 20 of Set 7 | takoradi
# Processing Record 21 of Set 7 | bokspits
# City not found.
# Processing Record 22 of Set 7 | alekseyevsk
# Processing Record 23 of Set 7 | sabzevar
# Processing Record 24 of Set 7 | anloga
# Processing Record 25 of Set 7 | nouadhibou
# Processing Record 26 of Set 7 | tandil
# Processing Record 27 of Set 7 | brokopondo
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | vestmannaeyjar
# Processing Record 31 of Set 7 | salaga
# Processing Record 32 of Set 7 | kristinehamn
# Processing Record 33 of Set 7 | itarema
# Processing Record 34 of Set 7 | kruisfontein
# Processing Record 35 of Set 7 | gibara
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | cabedelo
# Processing Record 38 of Set 7 | saskylakh
# Processing Record 39 of Set 7 | iracoubo
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | denpasar
# Processing Record 42 of Set 7 | paamiut
# Processing Record 43 of Set 7 | vardo
# Processing Record 44 of Set 7 | dourados
# Processing Record 45 of Set 7 | inderborskiy
# City not found.
# Processing Record 46 of Set 7 | hamilton
# Processing Record 47 of Set 7 | colac
# Processing Record 48 of Set 7 | cotonou
# Processing Record 49 of Set 7 | canon city
# Processing Record 50 of Set 7 | bocaranga
# City not found.
# Processing Record 1 of Set 8 | jining
# Processing Record 2 of Set 8 | oliveira do hospital
# Processing Record 3 of Set 8 | broome
# Processing Record 4 of Set 8 | paka
# Processing Record 5 of Set 8 | palabuhanratu
# City not found.
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | bonavista
# Processing Record 8 of Set 8 | tabiauea
# City not found.
# Processing Record 9 of Set 8 | odweyne
# Processing Record 10 of Set 8 | miraflores
# Processing Record 11 of Set 8 | rahatgarh
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | rio grande
# Processing Record 14 of Set 8 | jambi
# Processing Record 15 of Set 8 | grand river south east
# City not found.
# Processing Record 16 of Set 8 | poum
# Processing Record 17 of Set 8 | grindavik
# Processing Record 18 of Set 8 | waingapu
# Processing Record 19 of Set 8 | brenham
# Processing Record 20 of Set 8 | sumbawa
# City not found.
# Processing Record 21 of Set 8 | mega
# Processing Record 22 of Set 8 | sao luis de montes belos
# Processing Record 23 of Set 8 | hovd
# Processing Record 24 of Set 8 | praia
# Processing Record 25 of Set 8 | sentyabrskiy
# City not found.
# Processing Record 26 of Set 8 | umaria
# Processing Record 27 of Set 8 | burnie
# Processing Record 28 of Set 8 | taikang
# Processing Record 29 of Set 8 | guira de melena
# Processing Record 30 of Set 8 | nogliki
# Processing Record 31 of Set 8 | chudovo
# Processing Record 32 of Set 8 | namibe
# Processing Record 33 of Set 8 | vila franca do campo
# Processing Record 34 of Set 8 | mogadishu
# Processing Record 35 of Set 8 | hukuntsi
# Processing Record 36 of Set 8 | champerico
# Processing Record 37 of Set 8 | louisbourg
# City not found.
# Processing Record 38 of Set 8 | tarudant
# City not found.
# Processing Record 39 of Set 8 | camargo
# Processing Record 40 of Set 8 | mattru
# Processing Record 41 of Set 8 | ramnagar
# Processing Record 42 of Set 8 | bertoua
# Processing Record 43 of Set 8 | tengushevo
# Processing Record 44 of Set 8 | port blair
# Processing Record 45 of Set 8 | monte patria
# Processing Record 46 of Set 8 | buritama
# Processing Record 47 of Set 8 | crato
# Processing Record 48 of Set 8 | namtsy
# Processing Record 49 of Set 8 | svetlogorsk
# Processing Record 50 of Set 8 | ola
# Processing Record 1 of Set 9 | qom
# Processing Record 2 of Set 9 | natchez
# Processing Record 3 of Set 9 | yarovoye
# Processing Record 4 of Set 9 | buqayq
# City not found.
# Processing Record 5 of Set 9 | pokhara
# Processing Record 6 of Set 9 | nanortalik
# Processing Record 7 of Set 9 | alice springs
# Processing Record 8 of Set 9 | halalo
# City not found.
# Processing Record 9 of Set 9 | ponta delgada
# Processing Record 10 of Set 9 | cortes
# Processing Record 11 of Set 9 | livny
# Processing Record 12 of Set 9 | nelson bay
# Processing Record 13 of Set 9 | buraydah
# Processing Record 14 of Set 9 | sicamous
# Processing Record 15 of Set 9 | ishigaki
# Processing Record 16 of Set 9 | konnur
# Processing Record 17 of Set 9 | pacific grove
# Processing Record 18 of Set 9 | marovoay
# Processing Record 19 of Set 9 | smyrna
# Processing Record 20 of Set 9 | yamada
# Processing Record 21 of Set 9 | savannah bight
# Processing Record 22 of Set 9 | cururupu
# Processing Record 23 of Set 9 | saint-francois
# Processing Record 24 of Set 9 | houston
# Processing Record 25 of Set 9 | morgan city
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | bairiki
# Processing Record 28 of Set 9 | nalhati
# Processing Record 29 of Set 9 | yanchukan
# City not found.
# Processing Record 30 of Set 9 | athabasca
# Processing Record 31 of Set 9 | vaitupu
# City not found.
# Processing Record 32 of Set 9 | mankono
# Processing Record 33 of Set 9 | hambantota
# Processing Record 34 of Set 9 | cassilandia
# Processing Record 35 of Set 9 | gayny
# Processing Record 36 of Set 9 | jackson
# Processing Record 37 of Set 9 | methoni
# Processing Record 38 of Set 9 | ndele
# Processing Record 39 of Set 9 | taburi
# City not found.
# Processing Record 40 of Set 9 | conde
# Processing Record 41 of Set 9 | chapais
# Processing Record 42 of Set 9 | katangli
# Processing Record 43 of Set 9 | lovozero
# Processing Record 44 of Set 9 | lazaro cardenas
# Processing Record 45 of Set 9 | vadso
# Processing Record 46 of Set 9 | sabha
# Processing Record 47 of Set 9 | ngukurr
# City not found.
# Processing Record 48 of Set 9 | wronki
# Processing Record 49 of Set 9 | gallup
# Processing Record 50 of Set 9 | iqaluit
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | maloy
# Processing Record 3 of Set 10 | ust-nera
# Processing Record 4 of Set 10 | invermere
# Processing Record 5 of Set 10 | tungor
# Processing Record 6 of Set 10 | gatton
# Processing Record 7 of Set 10 | sharya
# Processing Record 8 of Set 10 | harper
# Processing Record 9 of Set 10 | ballina
# Processing Record 10 of Set 10 | moose factory
# Processing Record 11 of Set 10 | baker city
# Processing Record 12 of Set 10 | zakopane
# Processing Record 13 of Set 10 | sayyan
# Processing Record 14 of Set 10 | cernisoara
# Processing Record 15 of Set 10 | nara
# Processing Record 16 of Set 10 | sanchursk
# Processing Record 17 of Set 10 | gladstone
# Processing Record 18 of Set 10 | arica
# Processing Record 19 of Set 10 | dudinka
# Processing Record 20 of Set 10 | saravan
# Processing Record 21 of Set 10 | vikhorevka
# Processing Record 22 of Set 10 | teya
# Processing Record 23 of Set 10 | tuatapere
# Processing Record 24 of Set 10 | kazalinsk
# City not found.
# Processing Record 25 of Set 10 | marcona
# City not found.
# Processing Record 26 of Set 10 | borama
# City not found.
# Processing Record 27 of Set 10 | grakhovo
# Processing Record 28 of Set 10 | labuhan
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | yarim
# Processing Record 31 of Set 10 | kang
# Processing Record 32 of Set 10 | karakendzha
# City not found.
# Processing Record 33 of Set 10 | bitung
# Processing Record 34 of Set 10 | anshun
# Processing Record 35 of Set 10 | bambous virieux
# Processing Record 36 of Set 10 | langelsheim
# Processing Record 37 of Set 10 | shurugwi
# Processing Record 38 of Set 10 | tupik
# Processing Record 39 of Set 10 | nova olinda do norte
# Processing Record 40 of Set 10 | kaeo
# Processing Record 41 of Set 10 | maunabo
# Processing Record 42 of Set 10 | bagotville
# Processing Record 43 of Set 10 | momignies
# Processing Record 44 of Set 10 | santa fe
# Processing Record 45 of Set 10 | charleston
# Processing Record 46 of Set 10 | karratha
# Processing Record 47 of Set 10 | hun
# Processing Record 48 of Set 10 | nizhniy kuranakh
# Processing Record 49 of Set 10 | lowestoft
# Processing Record 50 of Set 10 | rawson
# Processing Record 1 of Set 11 | cabo san lucas
# Processing Record 2 of Set 11 | glasgow
# Processing Record 3 of Set 11 | farias brito
# Processing Record 4 of Set 11 | angoram
# Processing Record 5 of Set 11 | guangyuan
# Processing Record 6 of Set 11 | muborak
# Processing Record 7 of Set 11 | north platte
# Processing Record 8 of Set 11 | singleton
# Processing Record 9 of Set 11 | bardiyah
# Processing Record 10 of Set 11 | trinidad
# Processing Record 11 of Set 11 | mehamn
# Processing Record 12 of Set 11 | del rio
# Processing Record 13 of Set 11 | fort morgan
# Processing Record 14 of Set 11 | taber
# Processing Record 15 of Set 11 | pampierstad
# Processing Record 16 of Set 11 | ateli
# Processing Record 17 of Set 11 | adrar
# Processing Record 18 of Set 11 | tamiahua
# Processing Record 19 of Set 11 | sawtell
# Processing Record 20 of Set 11 | duma
# Processing Record 21 of Set 11 | phuntsholing
# Processing Record 22 of Set 11 | pizarro
# Processing Record 23 of Set 11 | fairbanks
# Processing Record 24 of Set 11 | lima
# Processing Record 25 of Set 11 | puerto asis
# Processing Record 26 of Set 11 | guiyang
# Processing Record 27 of Set 11 | kaitangata
# Processing Record 28 of Set 11 | harsesti
# Processing Record 29 of Set 11 | bukama
# Processing Record 30 of Set 11 | balaytigui
# City not found.
# Processing Record 31 of Set 11 | muisne
# Processing Record 32 of Set 11 | kargasok
# Processing Record 33 of Set 11 | prieska
# Processing Record 34 of Set 11 | wanning
# Processing Record 35 of Set 11 | batemans bay
# Processing Record 36 of Set 11 | los llanos de aridane
# Processing Record 37 of Set 11 | kralendijk
# Processing Record 38 of Set 11 | maningrida
# Processing Record 39 of Set 11 | algeciras
# Processing Record 40 of Set 11 | asau
# Processing Record 41 of Set 11 | san cristobal
# Processing Record 42 of Set 11 | vaitape
# Processing Record 43 of Set 11 | miri
# Processing Record 44 of Set 11 | sorland
# Processing Record 45 of Set 11 | rawah
# Processing Record 46 of Set 11 | balykshi
# Processing Record 47 of Set 11 | sinazongwe
# Processing Record 48 of Set 11 | guerrero negro
# Processing Record 49 of Set 11 | dzhusaly
# City not found.
# Processing Record 50 of Set 11 | kandrian
# Processing Record 1 of Set 12 | barth
# Processing Record 2 of Set 12 | jardim
# Processing Record 3 of Set 12 | fort nelson
# Processing Record 4 of Set 12 | butembo
# Processing Record 5 of Set 12 | totma
# Processing Record 6 of Set 12 | rondonopolis
# Processing Record 7 of Set 12 | derzhavinsk
# Processing Record 8 of Set 12 | biak
# Processing Record 9 of Set 12 | thunder bay
# Processing Record 10 of Set 12 | barguzin
# Processing Record 11 of Set 12 | meulaboh
# Processing Record 12 of Set 12 | kungurtug
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | corrales
# Processing Record 15 of Set 12 | hauterive
# Processing Record 16 of Set 12 | hengyang
# Processing Record 17 of Set 12 | guelph
# Processing Record 18 of Set 12 | monmouth
# Processing Record 19 of Set 12 | brae
# Processing Record 20 of Set 12 | fort wellington
# Processing Record 21 of Set 12 | calabozo
# Processing Record 22 of Set 12 | noyabrsk
# Processing Record 23 of Set 12 | warqla
# City not found.
# Processing Record 24 of Set 12 | kopanskaya
# Processing Record 25 of Set 12 | orange walk
# Processing Record 26 of Set 12 | candido mendes
# Processing Record 27 of Set 12 | mantua
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | bodden town
# Processing Record 30 of Set 12 | la ronge
# Processing Record 31 of Set 12 | dargaville
# Processing Record 32 of Set 12 | san rafael
# Processing Record 33 of Set 12 | puerto colombia
# Processing Record 34 of Set 12 | lancaster
# Processing Record 35 of Set 12 | tunduru
# City not found.
# Processing Record 36 of Set 12 | bay roberts
# Processing Record 37 of Set 12 | butiama
# Processing Record 38 of Set 12 | tingo maria
# Processing Record 39 of Set 12 | crotone
# Processing Record 40 of Set 12 | skjervoy
# Processing Record 41 of Set 12 | shitanjing
# Processing Record 42 of Set 12 | guacimo
# Processing Record 43 of Set 12 | bratsk
# Processing Record 44 of Set 12 | somerville
# Processing Record 45 of Set 12 | goya
# Processing Record 46 of Set 12 | tazovskiy
# Processing Record 47 of Set 12 | ray
# Processing Record 48 of Set 12 | sovetskiy
# Processing Record 49 of Set 12 | ulety
# Processing Record 50 of Set 12 | manggar
# Processing Record 1 of Set 13 | barcelona
# Processing Record 2 of Set 13 | alexandria
# Processing Record 3 of Set 13 | touros
# Processing Record 4 of Set 13 | north bend
# Processing Record 5 of Set 13 | kirkuk
# Processing Record 6 of Set 13 | xinqing
# Processing Record 7 of Set 13 | srednekolymsk
# Processing Record 8 of Set 13 | draguignan
# Processing Record 9 of Set 13 | bandarbeyla
# Processing Record 10 of Set 13 | osakarovka
# Processing Record 11 of Set 13 | bara
# Processing Record 12 of Set 13 | imeni poliny osipenko
# Processing Record 13 of Set 13 | lilongwe
# Processing Record 14 of Set 13 | douentza
# Processing Record 15 of Set 13 | flinders
# Processing Record 16 of Set 13 | bafq
# Processing Record 17 of Set 13 | huainan
# Processing Record 18 of Set 13 | shimoda
# Processing Record 19 of Set 13 | calvinia
# Processing Record 20 of Set 13 | sandwick
# Processing Record 21 of Set 13 | bogotol
# Processing Record 22 of Set 13 | yeppoon
# Processing Record 23 of Set 13 | yabrud
# Processing Record 24 of Set 13 | kailua
# Processing Record 25 of Set 13 | abonnema
# Processing Record 26 of Set 13 | comarapa
# Processing Record 27 of Set 13 | grahamstown
# Processing Record 28 of Set 13 | tiznit
# Processing Record 29 of Set 13 | salisbury
# Processing Record 30 of Set 13 | hailar
# Processing Record 31 of Set 13 | svetlaya
# Processing Record 32 of Set 13 | kadykchan
# City not found.
# Processing Record 33 of Set 13 | aasiaat
# Processing Record 34 of Set 13 | abha
# Processing Record 35 of Set 13 | tonstad
# Processing Record 36 of Set 13 | iranshahr
# Processing Record 37 of Set 13 | linxia
# Processing Record 38 of Set 13 | leh
# Processing Record 39 of Set 13 | cayenne
# Processing Record 40 of Set 13 | vallenar
# Processing Record 41 of Set 13 | khonuu
# City not found.
# Processing Record 42 of Set 13 | plettenberg bay
# Processing Record 43 of Set 13 | olafsvik
# Processing Record 44 of Set 13 | el badari
# City not found.
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | shingu
# Processing Record 47 of Set 13 | aykhal
# Processing Record 48 of Set 13 | haines junction
# Processing Record 49 of Set 13 | tawang
# Processing Record 50 of Set 13 | samarai
# Processing Record 1 of Set 14 | musoma
# Processing Record 2 of Set 14 | revda
# Processing Record 3 of Set 14 | sapa
# Processing Record 4 of Set 14 | sabang
# Processing Record 5 of Set 14 | bagdarin
# Processing Record 6 of Set 14 | bijie
# Processing Record 7 of Set 14 | nkoteng
# Processing Record 8 of Set 14 | pyapon
# Processing Record 9 of Set 14 | riwaka
# Processing Record 10 of Set 14 | morag
# Processing Record 11 of Set 14 | kloulklubed
# Processing Record 12 of Set 14 | terney
# Processing Record 13 of Set 14 | roebourne
# Processing Record 14 of Set 14 | kulhudhuffushi
# Processing Record 15 of Set 14 | riyadh
# Processing Record 16 of Set 14 | mareeba
# Processing Record 17 of Set 14 | paralia
# Processing Record 18 of Set 14 | fonte boa
# Processing Record 19 of Set 14 | kimberley
# Processing Record 20 of Set 14 | rundu
# Processing Record 21 of Set 14 | oranjemund
# Processing Record 22 of Set 14 | novoagansk
# Processing Record 23 of Set 14 | lahaina
# Processing Record 24 of Set 14 | nizwa
# Processing Record 25 of Set 14 | zelenoborsk
# Processing Record 26 of Set 14 | lisakovsk
# Processing Record 27 of Set 14 | tasbuget
# City not found.
# Processing Record 28 of Set 14 | campos belos
# Processing Record 29 of Set 14 | macaboboni
# City not found.
# Processing Record 30 of Set 14 | podor
# Processing Record 31 of Set 14 | xining
# Processing Record 32 of Set 14 | chapleau
# Processing Record 33 of Set 14 | oussouye
# Processing Record 34 of Set 14 | sehithwa
# Processing Record 35 of Set 14 | bargal
# City not found.
# Processing Record 36 of Set 14 | doaba
# Processing Record 37 of Set 14 | balkhash
# Processing Record 38 of Set 14 | kizhinga
# Processing Record 39 of Set 14 | ambunti
# Processing Record 40 of Set 14 | nagahama
# Processing Record 41 of Set 14 | beaufort
# Processing Record 42 of Set 14 | rolim de moura
# City not found.
# Processing Record 43 of Set 14 | nianzishan
# Processing Record 44 of Set 14 | andilamena
# Processing Record 45 of Set 14 | auki
# Processing Record 46 of Set 14 | torrington
# Processing Record 47 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 14 | vapnyarka
# Processing Record 49 of Set 14 | bonthe
# Processing Record 50 of Set 14 | naze
# Processing Record 1 of Set 15 | kuah
# Processing Record 2 of Set 15 | wulanhaote
# City not found.
# Processing Record 3 of Set 15 | sotnikovo
# Processing Record 4 of Set 15 | jacareacanga
# Processing Record 5 of Set 15 | kano
# Processing Record 6 of Set 15 | marabba
# Processing Record 7 of Set 15 | pueblo
# Processing Record 8 of Set 15 | kadhan
# Processing Record 9 of Set 15 | solovetskiy
# City not found.
# Processing Record 10 of Set 15 | abnub
# Processing Record 11 of Set 15 | lloro
# Processing Record 12 of Set 15 | corner brook
# Processing Record 13 of Set 15 | dese
# Processing Record 14 of Set 15 | sharjah
# Processing Record 15 of Set 15 | funtua
# Processing Record 16 of Set 15 | shimanovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     74.50        58          62
# 1        Buraydah      SA  26.3260   43.9750     39.65        33           0
# 2            Poum      NC -20.2333  164.0167     83.05        76          98
# 3        Karratha      AU -20.7377  116.8463     98.11        35          64
# 4        Gaborone      BW -24.6545   25.9086     62.51        77           0
# 5           Vaini      TO -21.2000 -175.2000     86.16        74          40
# 6     Tuktoyaktuk      CA  69.4541 -133.0374    -31.00        75          75
# 7          Torbay      CA  47.6666  -52.7314     32.76        87         100
# 8       Ostrovnoy      RU  68.0531   39.5131     21.24        83         100
# 9      Shitanjing      CN  39.2342  106.3439     20.03        49         100
#
#    Wind Speed Current Description
# 0        7.16       broken clouds
# 1        4.00           clear sky
# 2       11.30     overcast clouds
# 3        9.75       broken clouds
# 4        3.44           clear sky
# 5        8.05    scattered clouds
# 6        9.22       broken clouds
# 7       10.36     overcast clouds
# 8       26.93     overcast clouds
# 9        2.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
