# %%
# %matplotlib inline

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
cities
# Out:
# ['mananjary',
#  'hobart',
#  'egvekinot',
#  'lompoc',
#  'bluff',
#  'oskarshamn',
#  'narsaq',
#  'ushuaia',
#  'bredasdorp',
#  'illoqqortoormiut',
#  'albany',
#  'busselton',
#  'saint-philippe',
#  'coos bay',
#  'preston',
#  'coalcoman',
#  'hasaki',
#  'dikson',
#  'nizhneyansk',
#  'jimenez',
#  'attawapiskat',
#  'vaitape',
#  'stokmarknes',
#  'rikitea',
#  'georgetown',
#  'te anau',
#  'saleaula',
#  'flinders',
#  'kemijarvi',
#  'touros',
#  'port elizabeth',
#  'saskylakh',
#  'puerto ayora',
#  'aquidauana',
#  'longyearbyen',
#  'sandnessjoen',
#  'port hardy',
#  'hithadhoo',
#  'xinzhi',
#  'punta arenas',
#  'cape town',
#  'kruisfontein',
#  'richmond',
#  'lamar',
#  'ketchikan',
#  'barrow',
#  'vaini',
#  'port alfred',
#  'new norfolk',
#  'maumere',
#  'kapaa',
#  'yellowknife',
#  'atikokan',
#  'hofn',
#  'lagoa',
#  'meulaboh',
#  'marystown',
#  'andros town',
#  'poopo',
#  'san isidro',
#  'husavik',
#  'yauya',
#  'sibu',
#  'east london',
#  'chokurdakh',
#  'sexsmith',
#  'namibe',
#  'tanjong karang',
#  'marcona',
#  'mataura',
#  'vilyuysk',
#  'geraldton',
#  'naze',
#  'naranjal',
#  'mar del plata',
#  'havoysund',
#  'bambous virieux',
#  'victoria',
#  'buqayq',
#  'marzuq',
#  'mount isa',
#  'san cristobal',
#  'tagusao',
#  'fairbanks',
#  'amderma',
#  'hay river',
#  'gualeguay',
#  'codrington',
#  'cidreira',
#  'mahebourg',
#  'buraydah',
#  'souillac',
#  'lebu',
#  'tura',
#  'shu',
#  'mys shmidta',
#  'kavieng',
#  'tasiilaq',
#  'butaritari',
#  'fortuna',
#  'kahului',
#  'lodja',
#  'provideniya',
#  'ginebra',
#  'gazli',
#  'altay',
#  'clyde river',
#  'castro',
#  'ugoofaaru',
#  'tervel',
#  'vanavara',
#  'chuy',
#  'tocopilla',
#  'inhambane',
#  'tumannyy',
#  'gaurnadi',
#  'thompson',
#  'grand river south east',
#  'akyab',
#  'san quintin',
#  'wajir',
#  'passa quatro',
#  'ancud',
#  'huntsville',
#  'jamestown',
#  'margate',
#  'chore',
#  'severo-kurilsk',
#  'la ronge',
#  'kaa-khem',
#  'olinda',
#  'romanovskaya',
#  'belyy yar',
#  'vila franca do campo',
#  'port macquarie',
#  'caravelas',
#  'avarua',
#  'cabo san lucas',
#  'itoman',
#  'kununurra',
#  'barentsburg',
#  'manaia',
#  'eyl',
#  'isangel',
#  'cherskiy',
#  'khatanga',
#  'atuona',
#  'taolanaro',
#  'thinadhoo',
#  'jian',
#  'tuktoyaktuk',
#  'belushya guba',
#  'padang',
#  'carnarvon',
#  'dolbeau',
#  'plettenberg bay',
#  'tamandare',
#  'waingapu',
#  'ust-kamchatsk',
#  'bongandanga',
#  'hilo',
#  'airai',
#  'nanortalik',
#  'devyatka',
#  'saint george',
#  'ambo',
#  'klaksvik',
#  'port moresby',
#  'torbay',
#  'upernavik',
#  'ayr',
#  'goundam',
#  'moron',
#  'simijaca',
#  'soyo',
#  'yanam',
#  'williston',
#  'tuatapere',
#  'sinnamary',
#  'svetlaya',
#  'pacific grove',
#  'fevralsk',
#  'valparaiso',
#  'sovetsk',
#  'bethel',
#  'kodiak',
#  'hermanus',
#  'nikolskoye',
#  'bemidji',
#  'orapa',
#  'wattegama',
#  'svetlogorsk',
#  'hue',
#  'amahai',
#  'aklavik',
#  'kavaratti',
#  'batangafo',
#  'pauini',
#  'longlac',
#  'saint-francois',
#  'wau',
#  'campbell river',
#  'koumac',
#  'taoudenni',
#  'pemba',
#  'odlabari',
#  'montepuez',
#  'qaanaaq',
#  'lakselv',
#  'gravina in puglia',
#  'shambu',
#  'kenai',
#  'daru',
#  'torbat-e jam',
#  'sioux lookout',
#  'hovd',
#  'manta',
#  'morondava',
#  'ponta do sol',
#  'xinqing',
#  'mount gambier',
#  'broome',
#  'khandyga',
#  'pereslavl-zalesskiy',
#  'luderitz',
#  'baillif',
#  'minab',
#  'hami',
#  'santa cruz cabralia',
#  'aykhal',
#  'kulhudhuffushi',
#  'shache',
#  'burica',
#  'tongliao',
#  'alexandria',
#  'los llanos de aridane',
#  'guerrero negro',
#  'raga',
#  'juarez',
#  'iqaluit',
#  'marawi',
#  'lorengau',
#  'asse',
#  'suihua',
#  'bowen',
#  'lolua',
#  'hobyo',
#  'bengkulu',
#  'alofi',
#  'haines junction',
#  'cairns',
#  'grand forks',
#  'mianwali',
#  'sladkovo',
#  'avera',
#  'saint-georges',
#  'kuala terengganu',
#  'vaitupu',
#  'hoi an',
#  'mbeya',
#  'khingansk',
#  'ban tak',
#  'tabarqah',
#  'belaya gora',
#  'san patricio',
#  'sitka',
#  'nola',
#  'comodoro rivadavia',
#  'arraial do cabo',
#  'suicheng',
#  'ventspils',
#  'ruatoria',
#  'newport',
#  'tevriz',
#  'oriximina',
#  'rocha',
#  'tupik',
#  'meyungs',
#  'leningradskiy',
#  'tabas',
#  'nishihara',
#  'san ramon',
#  'key west',
#  'shiyan',
#  'sakakah',
#  'atasu',
#  'grand-lahou',
#  'muroto',
#  'tazovskiy',
#  'gorontalo',
#  'siavonga',
#  'kjollefjord',
#  'altinho',
#  'santa marta',
#  'grand gaube',
#  'tsihombe',
#  'fano',
#  'tilichiki',
#  'kaeo',
#  'barstow',
#  'sokoni',
#  'faya',
#  'barbar',
#  'yeehaw junction',
#  'makat',
#  'yatou',
#  'pochutla',
#  'lidkoping',
#  'ulaangom',
#  'constitucion',
#  'poum',
#  'kanker',
#  'vestmanna',
#  'dauriya',
#  'haibowan',
#  'gravdal',
#  'farafangana',
#  'nome',
#  'basco',
#  'calama',
#  'piryion',
#  'kamenskoye',
#  'belle fourche',
#  'kaitangata',
#  'cabo rojo',
#  'bubaque',
#  'abalak',
#  'ritchie',
#  'maracaju',
#  'rio gallegos',
#  'raudeberg',
#  'nemuro',
#  'samusu',
#  'abu kamal',
#  'tabou',
#  'ilulissat',
#  'chicama',
#  'opuwo',
#  'kalmunai',
#  'aksu',
#  'faanui',
#  'esperance',
#  'vao',
#  'beringovskiy',
#  'talnakh',
#  'sao felix do xingu',
#  'nazare',
#  'svetlyy',
#  'deputatskiy',
#  'ostrovnoy',
#  'lensk',
#  'okhotsk',
#  'emerald',
#  'moctezuma',
#  'nkowakowa',
#  'wittstock',
#  'lockport',
#  'tadine',
#  'aylmer',
#  'tiksi',
#  'ushtobe',
#  'moree',
#  'yulara',
#  'urucara',
#  'tarudant',
#  'columbus',
#  'macklin',
#  'male',
#  'sorong',
#  'hongjiang',
#  'saldanha',
#  'siyabuswa',
#  'waipawa',
#  'jalu',
#  'ribeira grande',
#  'coahuayana',
#  'ati',
#  'nassau',
#  'itarema',
#  'port-gentil',
#  'fukue',
#  'hihifo',
#  'bonavista',
#  'san francisco',
#  'saint anthony',
#  'gamba',
#  'chapais',
#  'seddon',
#  'half moon bay',
#  'pisco',
#  'mendi',
#  'rawannawi',
#  'karakendzha',
#  'klyuchi',
#  'puerto penasco',
#  'lima',
#  'tonj',
#  'sai buri',
#  'south lake tahoe',
#  'torma',
#  'ndele',
#  'katsuura',
#  'cockburn town',
#  'russell',
#  'marmande',
#  'nouna',
#  'chagda',
#  'lubao',
#  'seoul',
#  'byron bay',
#  'sentyabrskiy',
#  'chibombo',
#  'alice springs',
#  'ambilobe',
#  'baisha',
#  'ixtapa',
#  'camacha',
#  'bull savanna',
#  'cayenne',
#  'bathsheba',
#  'richards bay',
#  'altagracia de orituco',
#  'mecca',
#  'laguna',
#  'college',
#  'mangai',
#  'ginda',
#  'new castle',
#  'bandipur',
#  'chumikan',
#  'concord',
#  'barawe',
#  'prince rupert',
#  'manyana',
#  'zhanakorgan',
#  'hamilton',
#  'banda aceh',
#  'dryden',
#  'gloversville',
#  'port lincoln',
#  'lasa',
#  'great yarmouth',
#  'homer',
#  'phan thiet',
#  'qasigiannguit',
#  'sarandi',
#  'yar-sale',
#  'westport',
#  'lesozavodsk',
#  'baruun-urt',
#  'zhezkazgan',
#  'itacare',
#  'carlibaba',
#  'kloulklubed',
#  'batemans bay',
#  'cam ranh',
#  'moindou',
#  'marsa matruh',
#  'sorgun',
#  'sept-iles',
#  'salalah',
#  'balimo',
#  'khor',
#  'hokitika',
#  'bocas del toro',
#  'agadez',
#  'baglung',
#  'mantua',
#  'burnie',
#  'carikar',
#  'akhmim',
#  'boca do acre',
#  'houston',
#  'gambo',
#  'axim',
#  'san vicente',
#  'zhireken',
#  'chandler',
#  'pangnirtung',
#  'hambantota',
#  'ribas do rio pardo',
#  'becerril',
#  'sinegorskiy',
#  'nguiu',
#  'magrath',
#  'port blair',
#  'sarab',
#  'bulgan',
#  'ambulu',
#  'zapolyarnyy',
#  'prachuap khiri khan',
#  'bac lieu',
#  'umm kaddadah',
#  'temaraia',
#  'puerto carreno',
#  'bozdar',
#  'mogadishu',
#  'tonantins',
#  'saryshagan',
#  'sao filipe',
#  'pasco',
#  'asayita',
#  'khanu woralaksaburi',
#  'niquelandia',
#  'bontang',
#  'seydi',
#  'porto belo',
#  'norman wells',
#  'buchanan',
#  'grindavik',
#  'tchibanga',
#  'rio brilhante',
#  'muyezerskiy',
#  'bolshoye sorokino',
#  'luyang',
#  'karratha',
#  'altamont',
#  'hilton head island',
#  'lublin',
#  'atambua',
#  'shellbrook',
#  'palabuhanratu',
#  'paamiut',
#  'mechetinskaya',
#  'bosanci',
#  'olafsvik',
#  'skegness',
#  'coihueco',
#  'presidente medici',
#  'kajaani',
#  'hattiesburg',
#  'mackay',
#  'tawnat',
#  'harper',
#  'the pas',
#  'nagato',
#  'biu',
#  'chaves',
#  'shelburne',
#  'mayenne',
#  'mandan',
#  'ji-parana',
#  'areia branca',
#  'livingston',
#  'sedelnikovo',
#  'kropotkin',
#  'ksenyevka',
#  'oistins',
#  'chatra',
#  'nueva rosita',
#  'naftah',
#  'roebourne',
#  'dingle',
#  'lulea',
#  'bugiri',
#  'maragogi',
#  'ratnagiri',
#  'pitimbu',
#  'nelson bay',
#  'anapskaya',
#  'vardo',
#  'kidal',
#  'palu',
#  'boa vista',
#  'brae',
#  'gat',
#  'ngukurr',
#  'kaputa',
#  'zhangjiakou',
#  'galesong',
#  'skibbereen',
#  'ponta delgada',
#  'coquimbo',
#  'sharkan',
#  'cedar city',
#  'indergarh',
#  'fillan',
#  'sola',
#  'vostok',
#  'ahipara',
#  'kudahuvadhoo',
#  'coroata',
#  'aksarka',
#  'lisakovsk',
#  'aberdeen',
#  'sadiqabad',
#  'rosetta',
#  'zyryanka',
#  'tome',
#  'yining',
#  'jinchang',
#  'cardston',
#  'cariati',
#  'san andres',
#  'arriaga',
#  'sorland',
#  'kurumkan',
#  'broken hill',
#  'teguise',
#  'goderich',
#  'batagay-alyta',
#  'trincomalee',
#  'hualmay',
#  'djibo',
#  'cabedelo',
#  'ruidoso',
#  'barsovo',
#  'dakar',
#  'lubango',
#  'samalaeulu',
#  'rawson',
#  'sisimiut',
#  'moose factory',
#  'yunyang',
#  'bargal',
#  'warqla',
#  'whitehorse',
#  'taltal',
#  'cheremukhovo',
#  'hede',
#  'udachnyy',
#  'solovetskiy',
#  'gorele',
#  'lander',
#  'feijo',
#  'ulety',
#  'manokwari',
#  'utiroa',
#  'edd',
#  'lata',
#  'umm lajj',
#  'yaan',
#  'souris',
#  'fort smith',
#  'betong',
#  'zarate',
#  'omsukchan',
#  'springbok',
#  'ambon',
#  'samarai',
#  'moa',
#  'nuqui',
#  'srednekolymsk',
#  'moba',
#  'marrakesh',
#  'saint pete beach',
#  'mouzakion',
#  'umzimvubu',
#  'dolores',
#  'finnsnes',
#  'nhulunbuy',
#  'yichang',
#  'megion',
#  'hirara',
#  'balykshi',
#  'luanda',
#  'rock sound',
#  'kihei',
#  'sikea',
#  'shakawe',
#  'concordia',
#  'awbari',
#  'tessalit',
#  'orda',
#  'paraiso',
#  'curaca',
#  'muli',
#  'miraflores',
#  'nelson',
#  'tateyama',
#  'acapulco',
#  'sidi ali',
#  'dudinka',
#  'kedrovyy',
#  'saiha',
#  'oga',
#  'shubarshi',
#  'grand-santi',
#  'suntar',
#  'marienburg',
#  'quatre cocos',
#  'praia da vitoria',
#  'nouadhibou',
#  'portland',
#  'lodwar',
#  'havre-saint-pierre',
#  'north bend',
#  'bertea',
#  'da nang',
#  'ornes',
#  'bhadra',
#  'guaymas',
#  'tiznit',
#  'peniche',
#  'komsomolskiy',
#  'balkhash',
#  'sorsk',
#  'srbinovo',
#  'decatur',
#  'cavalcante',
#  'puerto madryn',
#  'dunedin',
#  'calamar',
#  'buritizeiro',
#  'sao gabriel da cachoeira',
#  'nyuksenitsa',
#  'kattivakkam',
#  'otane',
#  'picton',
#  'kuliyapitiya',
#  'qostanay',
#  'pangody',
#  'rudnichnyy',
#  'myitkyina',
#  'boende',
#  'azimur',
#  'coracao de jesus',
#  'bambanglipuro',
#  'auch',
#  'pevek',
#  'lecce',
#  'toliary',
#  'obodivka',
#  'talara',
#  'gusau',
#  'campos do jordao',
#  'morant bay',
#  'codajas',
#  'charyshskoye',
#  'tomatlan',
#  'shingu',
#  'madimba',
#  'tautira',
#  'sikonge',
#  'taburi',
#  'balagansk',
#  'lenine',
#  'kysyl-syr',
#  'morros',
#  'sungaipenuh',
#  'moletai',
#  'houma',
#  'qandala',
#  'kandrian',
#  'lahaina',
#  'zhigansk',
#  'stillwater',
#  'jining',
#  'alugan',
#  'othaya',
#  'machachi']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# set counters.
record_count = 1
set_count = 1

print("-----------------------------")
print("Beginning Dara Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city  in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found.")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Beginning Dara Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mananjary
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | egvekinot
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | oskarshamn
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found.
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | coos bay
# Processing Record 15 of Set 1 | preston
# Processing Record 16 of Set 1 | coalcoman
# City not found.
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | nizhneyansk
# City not found.
# Processing Record 20 of Set 1 | jimenez
# Processing Record 21 of Set 1 | attawapiskat
# City not found.
# Processing Record 22 of Set 1 | vaitape
# Processing Record 23 of Set 1 | stokmarknes
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | saleaula
# City not found.
# Processing Record 28 of Set 1 | flinders
# Processing Record 29 of Set 1 | kemijarvi
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | aquidauana
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | sandnessjoen
# Processing Record 37 of Set 1 | port hardy
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | xinzhi
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | richmond
# Processing Record 44 of Set 1 | lamar
# Processing Record 45 of Set 1 | ketchikan
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | maumere
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | atikokan
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | marystown
# Processing Record 8 of Set 2 | andros town
# Processing Record 9 of Set 2 | poopo
# Processing Record 10 of Set 2 | san isidro
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | yauya
# Processing Record 13 of Set 2 | sibu
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | sexsmith
# Processing Record 17 of Set 2 | namibe
# Processing Record 18 of Set 2 | tanjong karang
# City not found.
# Processing Record 19 of Set 2 | marcona
# City not found.
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | vilyuysk
# Processing Record 22 of Set 2 | geraldton
# Processing Record 23 of Set 2 | naze
# Processing Record 24 of Set 2 | naranjal
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | havoysund
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | buqayq
# City not found.
# Processing Record 30 of Set 2 | marzuq
# Processing Record 31 of Set 2 | mount isa
# Processing Record 32 of Set 2 | san cristobal
# Processing Record 33 of Set 2 | tagusao
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | amderma
# City not found.
# Processing Record 36 of Set 2 | hay river
# Processing Record 37 of Set 2 | gualeguay
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | buraydah
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | shu
# Processing Record 46 of Set 2 | mys shmidta
# City not found.
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | kahului
# Processing Record 2 of Set 3 | lodja
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | ginebra
# Processing Record 5 of Set 3 | gazli
# Processing Record 6 of Set 3 | altay
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | ugoofaaru
# Processing Record 10 of Set 3 | tervel
# Processing Record 11 of Set 3 | vanavara
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | tocopilla
# Processing Record 14 of Set 3 | inhambane
# Processing Record 15 of Set 3 | tumannyy
# City not found.
# Processing Record 16 of Set 3 | gaurnadi
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | grand river south east
# City not found.
# Processing Record 19 of Set 3 | akyab
# Processing Record 20 of Set 3 | san quintin
# Processing Record 21 of Set 3 | wajir
# Processing Record 22 of Set 3 | passa quatro
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | huntsville
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | margate
# Processing Record 27 of Set 3 | chore
# City not found.
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | la ronge
# Processing Record 30 of Set 3 | kaa-khem
# Processing Record 31 of Set 3 | olinda
# Processing Record 32 of Set 3 | romanovskaya
# Processing Record 33 of Set 3 | belyy yar
# Processing Record 34 of Set 3 | vila franca do campo
# Processing Record 35 of Set 3 | port macquarie
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | itoman
# Processing Record 40 of Set 3 | kununurra
# Processing Record 41 of Set 3 | barentsburg
# City not found.
# Processing Record 42 of Set 3 | manaia
# Processing Record 43 of Set 3 | eyl
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | atuona
# Processing Record 48 of Set 3 | taolanaro
# City not found.
# Processing Record 49 of Set 3 | thinadhoo
# Processing Record 50 of Set 3 | jian
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | belushya guba
# City not found.
# Processing Record 3 of Set 4 | padang
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | dolbeau
# City not found.
# Processing Record 6 of Set 4 | plettenberg bay
# Processing Record 7 of Set 4 | tamandare
# Processing Record 8 of Set 4 | waingapu
# Processing Record 9 of Set 4 | ust-kamchatsk
# City not found.
# Processing Record 10 of Set 4 | bongandanga
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | devyatka
# City not found.
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | ambo
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | port moresby
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | ayr
# Processing Record 22 of Set 4 | goundam
# Processing Record 23 of Set 4 | moron
# Processing Record 24 of Set 4 | simijaca
# Processing Record 25 of Set 4 | soyo
# Processing Record 26 of Set 4 | yanam
# Processing Record 27 of Set 4 | williston
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | svetlaya
# Processing Record 31 of Set 4 | pacific grove
# Processing Record 32 of Set 4 | fevralsk
# City not found.
# Processing Record 33 of Set 4 | valparaiso
# Processing Record 34 of Set 4 | sovetsk
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | hermanus
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | bemidji
# Processing Record 40 of Set 4 | orapa
# Processing Record 41 of Set 4 | wattegama
# Processing Record 42 of Set 4 | svetlogorsk
# Processing Record 43 of Set 4 | hue
# Processing Record 44 of Set 4 | amahai
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | kavaratti
# Processing Record 47 of Set 4 | batangafo
# Processing Record 48 of Set 4 | pauini
# Processing Record 49 of Set 4 | longlac
# City not found.
# Processing Record 50 of Set 4 | saint-francois
# Processing Record 1 of Set 5 | wau
# Processing Record 2 of Set 5 | campbell river
# Processing Record 3 of Set 5 | koumac
# Processing Record 4 of Set 5 | taoudenni
# Processing Record 5 of Set 5 | pemba
# Processing Record 6 of Set 5 | odlabari
# Processing Record 7 of Set 5 | montepuez
# Processing Record 8 of Set 5 | qaanaaq
# Processing Record 9 of Set 5 | lakselv
# Processing Record 10 of Set 5 | gravina in puglia
# Processing Record 11 of Set 5 | shambu
# Processing Record 12 of Set 5 | kenai
# Processing Record 13 of Set 5 | daru
# Processing Record 14 of Set 5 | torbat-e jam
# Processing Record 15 of Set 5 | sioux lookout
# Processing Record 16 of Set 5 | hovd
# Processing Record 17 of Set 5 | manta
# Processing Record 18 of Set 5 | morondava
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | xinqing
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | broome
# Processing Record 23 of Set 5 | khandyga
# Processing Record 24 of Set 5 | pereslavl-zalesskiy
# Processing Record 25 of Set 5 | luderitz
# Processing Record 26 of Set 5 | baillif
# Processing Record 27 of Set 5 | minab
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | santa cruz cabralia
# Processing Record 30 of Set 5 | aykhal
# Processing Record 31 of Set 5 | kulhudhuffushi
# Processing Record 32 of Set 5 | shache
# Processing Record 33 of Set 5 | burica
# City not found.
# Processing Record 34 of Set 5 | tongliao
# Processing Record 35 of Set 5 | alexandria
# Processing Record 36 of Set 5 | los llanos de aridane
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | raga
# Processing Record 39 of Set 5 | juarez
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | asse
# Processing Record 44 of Set 5 | suihua
# Processing Record 45 of Set 5 | bowen
# Processing Record 46 of Set 5 | lolua
# City not found.
# Processing Record 47 of Set 5 | hobyo
# Processing Record 48 of Set 5 | bengkulu
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | cairns
# Processing Record 2 of Set 6 | grand forks
# Processing Record 3 of Set 6 | mianwali
# Processing Record 4 of Set 6 | sladkovo
# Processing Record 5 of Set 6 | avera
# Processing Record 6 of Set 6 | saint-georges
# Processing Record 7 of Set 6 | kuala terengganu
# Processing Record 8 of Set 6 | vaitupu
# City not found.
# Processing Record 9 of Set 6 | hoi an
# Processing Record 10 of Set 6 | mbeya
# Processing Record 11 of Set 6 | khingansk
# Processing Record 12 of Set 6 | ban tak
# Processing Record 13 of Set 6 | tabarqah
# City not found.
# Processing Record 14 of Set 6 | belaya gora
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | nola
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | arraial do cabo
# Processing Record 20 of Set 6 | suicheng
# Processing Record 21 of Set 6 | ventspils
# Processing Record 22 of Set 6 | ruatoria
# City not found.
# Processing Record 23 of Set 6 | newport
# Processing Record 24 of Set 6 | tevriz
# Processing Record 25 of Set 6 | oriximina
# Processing Record 26 of Set 6 | rocha
# Processing Record 27 of Set 6 | tupik
# Processing Record 28 of Set 6 | meyungs
# City not found.
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | tabas
# Processing Record 31 of Set 6 | nishihara
# Processing Record 32 of Set 6 | san ramon
# Processing Record 33 of Set 6 | key west
# Processing Record 34 of Set 6 | shiyan
# Processing Record 35 of Set 6 | sakakah
# Processing Record 36 of Set 6 | atasu
# Processing Record 37 of Set 6 | grand-lahou
# Processing Record 38 of Set 6 | muroto
# Processing Record 39 of Set 6 | tazovskiy
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | siavonga
# Processing Record 42 of Set 6 | kjollefjord
# Processing Record 43 of Set 6 | altinho
# Processing Record 44 of Set 6 | santa marta
# Processing Record 45 of Set 6 | grand gaube
# Processing Record 46 of Set 6 | tsihombe
# City not found.
# Processing Record 47 of Set 6 | fano
# Processing Record 48 of Set 6 | tilichiki
# Processing Record 49 of Set 6 | kaeo
# Processing Record 50 of Set 6 | barstow
# Processing Record 1 of Set 7 | sokoni
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | barbar
# City not found.
# Processing Record 4 of Set 7 | yeehaw junction
# City not found.
# Processing Record 5 of Set 7 | makat
# Processing Record 6 of Set 7 | yatou
# Processing Record 7 of Set 7 | pochutla
# Processing Record 8 of Set 7 | lidkoping
# Processing Record 9 of Set 7 | ulaangom
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | poum
# Processing Record 12 of Set 7 | kanker
# Processing Record 13 of Set 7 | vestmanna
# Processing Record 14 of Set 7 | dauriya
# Processing Record 15 of Set 7 | haibowan
# City not found.
# Processing Record 16 of Set 7 | gravdal
# Processing Record 17 of Set 7 | farafangana
# Processing Record 18 of Set 7 | nome
# Processing Record 19 of Set 7 | basco
# Processing Record 20 of Set 7 | calama
# Processing Record 21 of Set 7 | piryion
# City not found.
# Processing Record 22 of Set 7 | kamenskoye
# City not found.
# Processing Record 23 of Set 7 | belle fourche
# Processing Record 24 of Set 7 | kaitangata
# Processing Record 25 of Set 7 | cabo rojo
# Processing Record 26 of Set 7 | bubaque
# Processing Record 27 of Set 7 | abalak
# Processing Record 28 of Set 7 | ritchie
# Processing Record 29 of Set 7 | maracaju
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | raudeberg
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | samusu
# City not found.
# Processing Record 34 of Set 7 | abu kamal
# Processing Record 35 of Set 7 | tabou
# Processing Record 36 of Set 7 | ilulissat
# Processing Record 37 of Set 7 | chicama
# Processing Record 38 of Set 7 | opuwo
# Processing Record 39 of Set 7 | kalmunai
# Processing Record 40 of Set 7 | aksu
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | vao
# Processing Record 44 of Set 7 | beringovskiy
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | sao felix do xingu
# Processing Record 47 of Set 7 | nazare
# Processing Record 48 of Set 7 | svetlyy
# Processing Record 49 of Set 7 | deputatskiy
# Processing Record 50 of Set 7 | ostrovnoy
# Processing Record 1 of Set 8 | lensk
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | moctezuma
# Processing Record 5 of Set 8 | nkowakowa
# Processing Record 6 of Set 8 | wittstock
# Processing Record 7 of Set 8 | lockport
# Processing Record 8 of Set 8 | tadine
# Processing Record 9 of Set 8 | aylmer
# Processing Record 10 of Set 8 | tiksi
# Processing Record 11 of Set 8 | ushtobe
# Processing Record 12 of Set 8 | moree
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | urucara
# Processing Record 15 of Set 8 | tarudant
# City not found.
# Processing Record 16 of Set 8 | columbus
# Processing Record 17 of Set 8 | macklin
# Processing Record 18 of Set 8 | male
# Processing Record 19 of Set 8 | sorong
# Processing Record 20 of Set 8 | hongjiang
# Processing Record 21 of Set 8 | saldanha
# Processing Record 22 of Set 8 | siyabuswa
# Processing Record 23 of Set 8 | waipawa
# Processing Record 24 of Set 8 | jalu
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | coahuayana
# Processing Record 27 of Set 8 | ati
# Processing Record 28 of Set 8 | nassau
# Processing Record 29 of Set 8 | itarema
# Processing Record 30 of Set 8 | port-gentil
# Processing Record 31 of Set 8 | fukue
# Processing Record 32 of Set 8 | hihifo
# City not found.
# Processing Record 33 of Set 8 | bonavista
# Processing Record 34 of Set 8 | san francisco
# Processing Record 35 of Set 8 | saint anthony
# Processing Record 36 of Set 8 | gamba
# Processing Record 37 of Set 8 | chapais
# Processing Record 38 of Set 8 | seddon
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | pisco
# Processing Record 41 of Set 8 | mendi
# Processing Record 42 of Set 8 | rawannawi
# City not found.
# Processing Record 43 of Set 8 | karakendzha
# City not found.
# Processing Record 44 of Set 8 | klyuchi
# Processing Record 45 of Set 8 | puerto penasco
# Processing Record 46 of Set 8 | lima
# Processing Record 47 of Set 8 | tonj
# Processing Record 48 of Set 8 | sai buri
# Processing Record 49 of Set 8 | south lake tahoe
# Processing Record 50 of Set 8 | torma
# Processing Record 1 of Set 9 | ndele
# Processing Record 2 of Set 9 | katsuura
# Processing Record 3 of Set 9 | cockburn town
# Processing Record 4 of Set 9 | russell
# Processing Record 5 of Set 9 | marmande
# Processing Record 6 of Set 9 | nouna
# Processing Record 7 of Set 9 | chagda
# City not found.
# Processing Record 8 of Set 9 | lubao
# Processing Record 9 of Set 9 | seoul
# Processing Record 10 of Set 9 | byron bay
# Processing Record 11 of Set 9 | sentyabrskiy
# City not found.
# Processing Record 12 of Set 9 | chibombo
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | ambilobe
# Processing Record 15 of Set 9 | baisha
# Processing Record 16 of Set 9 | ixtapa
# Processing Record 17 of Set 9 | camacha
# Processing Record 18 of Set 9 | bull savanna
# Processing Record 19 of Set 9 | cayenne
# Processing Record 20 of Set 9 | bathsheba
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | altagracia de orituco
# Processing Record 23 of Set 9 | mecca
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | mangai
# Processing Record 27 of Set 9 | ginda
# Processing Record 28 of Set 9 | new castle
# Processing Record 29 of Set 9 | bandipur
# Processing Record 30 of Set 9 | chumikan
# Processing Record 31 of Set 9 | concord
# Processing Record 32 of Set 9 | barawe
# City not found.
# Processing Record 33 of Set 9 | prince rupert
# Processing Record 34 of Set 9 | manyana
# Processing Record 35 of Set 9 | zhanakorgan
# Processing Record 36 of Set 9 | hamilton
# Processing Record 37 of Set 9 | banda aceh
# Processing Record 38 of Set 9 | dryden
# Processing Record 39 of Set 9 | gloversville
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | lasa
# Processing Record 42 of Set 9 | great yarmouth
# Processing Record 43 of Set 9 | homer
# Processing Record 44 of Set 9 | phan thiet
# Processing Record 45 of Set 9 | qasigiannguit
# Processing Record 46 of Set 9 | sarandi
# Processing Record 47 of Set 9 | yar-sale
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | lesozavodsk
# Processing Record 50 of Set 9 | baruun-urt
# Processing Record 1 of Set 10 | zhezkazgan
# Processing Record 2 of Set 10 | itacare
# Processing Record 3 of Set 10 | carlibaba
# Processing Record 4 of Set 10 | kloulklubed
# Processing Record 5 of Set 10 | batemans bay
# Processing Record 6 of Set 10 | cam ranh
# Processing Record 7 of Set 10 | moindou
# Processing Record 8 of Set 10 | marsa matruh
# Processing Record 9 of Set 10 | sorgun
# Processing Record 10 of Set 10 | sept-iles
# Processing Record 11 of Set 10 | salalah
# Processing Record 12 of Set 10 | balimo
# City not found.
# Processing Record 13 of Set 10 | khor
# Processing Record 14 of Set 10 | hokitika
# Processing Record 15 of Set 10 | bocas del toro
# Processing Record 16 of Set 10 | agadez
# Processing Record 17 of Set 10 | baglung
# Processing Record 18 of Set 10 | mantua
# Processing Record 19 of Set 10 | burnie
# Processing Record 20 of Set 10 | carikar
# City not found.
# Processing Record 21 of Set 10 | akhmim
# Processing Record 22 of Set 10 | boca do acre
# Processing Record 23 of Set 10 | houston
# Processing Record 24 of Set 10 | gambo
# Processing Record 25 of Set 10 | axim
# Processing Record 26 of Set 10 | san vicente
# Processing Record 27 of Set 10 | zhireken
# Processing Record 28 of Set 10 | chandler
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | ribas do rio pardo
# Processing Record 32 of Set 10 | becerril
# Processing Record 33 of Set 10 | sinegorskiy
# Processing Record 34 of Set 10 | nguiu
# City not found.
# Processing Record 35 of Set 10 | magrath
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | sarab
# Processing Record 38 of Set 10 | bulgan
# Processing Record 39 of Set 10 | ambulu
# Processing Record 40 of Set 10 | zapolyarnyy
# Processing Record 41 of Set 10 | prachuap khiri khan
# Processing Record 42 of Set 10 | bac lieu
# Processing Record 43 of Set 10 | umm kaddadah
# Processing Record 44 of Set 10 | temaraia
# City not found.
# Processing Record 45 of Set 10 | puerto carreno
# Processing Record 46 of Set 10 | bozdar
# Processing Record 47 of Set 10 | mogadishu
# Processing Record 48 of Set 10 | tonantins
# Processing Record 49 of Set 10 | saryshagan
# City not found.
# Processing Record 50 of Set 10 | sao filipe
# Processing Record 1 of Set 11 | pasco
# Processing Record 2 of Set 11 | asayita
# City not found.
# Processing Record 3 of Set 11 | khanu woralaksaburi
# Processing Record 4 of Set 11 | niquelandia
# Processing Record 5 of Set 11 | bontang
# Processing Record 6 of Set 11 | seydi
# Processing Record 7 of Set 11 | porto belo
# Processing Record 8 of Set 11 | norman wells
# Processing Record 9 of Set 11 | buchanan
# Processing Record 10 of Set 11 | grindavik
# Processing Record 11 of Set 11 | tchibanga
# Processing Record 12 of Set 11 | rio brilhante
# Processing Record 13 of Set 11 | muyezerskiy
# Processing Record 14 of Set 11 | bolshoye sorokino
# City not found.
# Processing Record 15 of Set 11 | luyang
# Processing Record 16 of Set 11 | karratha
# Processing Record 17 of Set 11 | altamont
# Processing Record 18 of Set 11 | hilton head island
# Processing Record 19 of Set 11 | lublin
# Processing Record 20 of Set 11 | atambua
# Processing Record 21 of Set 11 | shellbrook
# Processing Record 22 of Set 11 | palabuhanratu
# City not found.
# Processing Record 23 of Set 11 | paamiut
# Processing Record 24 of Set 11 | mechetinskaya
# Processing Record 25 of Set 11 | bosanci
# Processing Record 26 of Set 11 | olafsvik
# Processing Record 27 of Set 11 | skegness
# Processing Record 28 of Set 11 | coihueco
# Processing Record 29 of Set 11 | presidente medici
# Processing Record 30 of Set 11 | kajaani
# Processing Record 31 of Set 11 | hattiesburg
# Processing Record 32 of Set 11 | mackay
# Processing Record 33 of Set 11 | tawnat
# City not found.
# Processing Record 34 of Set 11 | harper
# Processing Record 35 of Set 11 | the pas
# Processing Record 36 of Set 11 | nagato
# Processing Record 37 of Set 11 | biu
# Processing Record 38 of Set 11 | chaves
# Processing Record 39 of Set 11 | shelburne
# Processing Record 40 of Set 11 | mayenne
# Processing Record 41 of Set 11 | mandan
# Processing Record 42 of Set 11 | ji-parana
# City not found.
# Processing Record 43 of Set 11 | areia branca
# Processing Record 44 of Set 11 | livingston
# Processing Record 45 of Set 11 | sedelnikovo
# City not found.
# Processing Record 46 of Set 11 | kropotkin
# Processing Record 47 of Set 11 | ksenyevka
# City not found.
# Processing Record 48 of Set 11 | oistins
# Processing Record 49 of Set 11 | chatra
# Processing Record 50 of Set 11 | nueva rosita
# Processing Record 1 of Set 12 | naftah
# City not found.
# Processing Record 2 of Set 12 | roebourne
# Processing Record 3 of Set 12 | dingle
# Processing Record 4 of Set 12 | lulea
# Processing Record 5 of Set 12 | bugiri
# Processing Record 6 of Set 12 | maragogi
# Processing Record 7 of Set 12 | ratnagiri
# Processing Record 8 of Set 12 | pitimbu
# Processing Record 9 of Set 12 | nelson bay
# Processing Record 10 of Set 12 | anapskaya
# Processing Record 11 of Set 12 | vardo
# Processing Record 12 of Set 12 | kidal
# Processing Record 13 of Set 12 | palu
# Processing Record 14 of Set 12 | boa vista
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | gat
# Processing Record 17 of Set 12 | ngukurr
# City not found.
# Processing Record 18 of Set 12 | kaputa
# Processing Record 19 of Set 12 | zhangjiakou
# Processing Record 20 of Set 12 | galesong
# Processing Record 21 of Set 12 | skibbereen
# Processing Record 22 of Set 12 | ponta delgada
# Processing Record 23 of Set 12 | coquimbo
# Processing Record 24 of Set 12 | sharkan
# Processing Record 25 of Set 12 | cedar city
# Processing Record 26 of Set 12 | indergarh
# Processing Record 27 of Set 12 | fillan
# Processing Record 28 of Set 12 | sola
# Processing Record 29 of Set 12 | vostok
# Processing Record 30 of Set 12 | ahipara
# Processing Record 31 of Set 12 | kudahuvadhoo
# Processing Record 32 of Set 12 | coroata
# Processing Record 33 of Set 12 | aksarka
# Processing Record 34 of Set 12 | lisakovsk
# Processing Record 35 of Set 12 | aberdeen
# Processing Record 36 of Set 12 | sadiqabad
# Processing Record 37 of Set 12 | rosetta
# Processing Record 38 of Set 12 | zyryanka
# Processing Record 39 of Set 12 | tome
# Processing Record 40 of Set 12 | yining
# Processing Record 41 of Set 12 | jinchang
# Processing Record 42 of Set 12 | cardston
# Processing Record 43 of Set 12 | cariati
# Processing Record 44 of Set 12 | san andres
# Processing Record 45 of Set 12 | arriaga
# Processing Record 46 of Set 12 | sorland
# Processing Record 47 of Set 12 | kurumkan
# Processing Record 48 of Set 12 | broken hill
# Processing Record 49 of Set 12 | teguise
# Processing Record 50 of Set 12 | goderich
# Processing Record 1 of Set 13 | batagay-alyta
# Processing Record 2 of Set 13 | trincomalee
# Processing Record 3 of Set 13 | hualmay
# Processing Record 4 of Set 13 | djibo
# Processing Record 5 of Set 13 | cabedelo
# Processing Record 6 of Set 13 | ruidoso
# Processing Record 7 of Set 13 | barsovo
# Processing Record 8 of Set 13 | dakar
# Processing Record 9 of Set 13 | lubango
# Processing Record 10 of Set 13 | samalaeulu
# City not found.
# Processing Record 11 of Set 13 | rawson
# Processing Record 12 of Set 13 | sisimiut
# Processing Record 13 of Set 13 | moose factory
# Processing Record 14 of Set 13 | yunyang
# Processing Record 15 of Set 13 | bargal
# City not found.
# Processing Record 16 of Set 13 | warqla
# City not found.
# Processing Record 17 of Set 13 | whitehorse
# Processing Record 18 of Set 13 | taltal
# Processing Record 19 of Set 13 | cheremukhovo
# Processing Record 20 of Set 13 | hede
# Processing Record 21 of Set 13 | udachnyy
# Processing Record 22 of Set 13 | solovetskiy
# City not found.
# Processing Record 23 of Set 13 | gorele
# Processing Record 24 of Set 13 | lander
# Processing Record 25 of Set 13 | feijo
# Processing Record 26 of Set 13 | ulety
# Processing Record 27 of Set 13 | manokwari
# Processing Record 28 of Set 13 | utiroa
# City not found.
# Processing Record 29 of Set 13 | edd
# Processing Record 30 of Set 13 | lata
# Processing Record 31 of Set 13 | umm lajj
# Processing Record 32 of Set 13 | yaan
# Processing Record 33 of Set 13 | souris
# Processing Record 34 of Set 13 | fort smith
# Processing Record 35 of Set 13 | betong
# Processing Record 36 of Set 13 | zarate
# Processing Record 37 of Set 13 | omsukchan
# Processing Record 38 of Set 13 | springbok
# Processing Record 39 of Set 13 | ambon
# Processing Record 40 of Set 13 | samarai
# Processing Record 41 of Set 13 | moa
# Processing Record 42 of Set 13 | nuqui
# Processing Record 43 of Set 13 | srednekolymsk
# Processing Record 44 of Set 13 | moba
# Processing Record 45 of Set 13 | marrakesh
# Processing Record 46 of Set 13 | saint pete beach
# Processing Record 47 of Set 13 | mouzakion
# City not found.
# Processing Record 48 of Set 13 | umzimvubu
# City not found.
# Processing Record 49 of Set 13 | dolores
# Processing Record 50 of Set 13 | finnsnes
# Processing Record 1 of Set 14 | nhulunbuy
# Processing Record 2 of Set 14 | yichang
# Processing Record 3 of Set 14 | megion
# Processing Record 4 of Set 14 | hirara
# Processing Record 5 of Set 14 | balykshi
# Processing Record 6 of Set 14 | luanda
# Processing Record 7 of Set 14 | rock sound
# Processing Record 8 of Set 14 | kihei
# Processing Record 9 of Set 14 | sikea
# City not found.
# Processing Record 10 of Set 14 | shakawe
# Processing Record 11 of Set 14 | concordia
# Processing Record 12 of Set 14 | awbari
# Processing Record 13 of Set 14 | tessalit
# Processing Record 14 of Set 14 | orda
# Processing Record 15 of Set 14 | paraiso
# Processing Record 16 of Set 14 | curaca
# Processing Record 17 of Set 14 | muli
# Processing Record 18 of Set 14 | miraflores
# Processing Record 19 of Set 14 | nelson
# Processing Record 20 of Set 14 | tateyama
# Processing Record 21 of Set 14 | acapulco
# Processing Record 22 of Set 14 | sidi ali
# Processing Record 23 of Set 14 | dudinka
# Processing Record 24 of Set 14 | kedrovyy
# Processing Record 25 of Set 14 | saiha
# Processing Record 26 of Set 14 | oga
# Processing Record 27 of Set 14 | shubarshi
# Processing Record 28 of Set 14 | grand-santi
# Processing Record 29 of Set 14 | suntar
# Processing Record 30 of Set 14 | marienburg
# Processing Record 31 of Set 14 | quatre cocos
# Processing Record 32 of Set 14 | praia da vitoria
# Processing Record 33 of Set 14 | nouadhibou
# Processing Record 34 of Set 14 | portland
# Processing Record 35 of Set 14 | lodwar
# Processing Record 36 of Set 14 | havre-saint-pierre
# Processing Record 37 of Set 14 | north bend
# Processing Record 38 of Set 14 | bertea
# Processing Record 39 of Set 14 | da nang
# Processing Record 40 of Set 14 | ornes
# Processing Record 41 of Set 14 | bhadra
# Processing Record 42 of Set 14 | guaymas
# Processing Record 43 of Set 14 | tiznit
# Processing Record 44 of Set 14 | peniche
# Processing Record 45 of Set 14 | komsomolskiy
# Processing Record 46 of Set 14 | balkhash
# Processing Record 47 of Set 14 | sorsk
# Processing Record 48 of Set 14 | srbinovo
# Processing Record 49 of Set 14 | decatur
# Processing Record 50 of Set 14 | cavalcante
# Processing Record 1 of Set 15 | puerto madryn
# Processing Record 2 of Set 15 | dunedin
# Processing Record 3 of Set 15 | calamar
# Processing Record 4 of Set 15 | buritizeiro
# Processing Record 5 of Set 15 | sao gabriel da cachoeira
# Processing Record 6 of Set 15 | nyuksenitsa
# Processing Record 7 of Set 15 | kattivakkam
# Processing Record 8 of Set 15 | otane
# Processing Record 9 of Set 15 | picton
# Processing Record 10 of Set 15 | kuliyapitiya
# Processing Record 11 of Set 15 | qostanay
# Processing Record 12 of Set 15 | pangody
# Processing Record 13 of Set 15 | rudnichnyy
# Processing Record 14 of Set 15 | myitkyina
# Processing Record 15 of Set 15 | boende
# Processing Record 16 of Set 15 | azimur
# City not found.
# Processing Record 17 of Set 15 | coracao de jesus
# Processing Record 18 of Set 15 | bambanglipuro
# Processing Record 19 of Set 15 | auch
# Processing Record 20 of Set 15 | pevek
# Processing Record 21 of Set 15 | lecce
# Processing Record 22 of Set 15 | toliary
# City not found.
# Processing Record 23 of Set 15 | obodivka
# Processing Record 24 of Set 15 | talara
# Processing Record 25 of Set 15 | gusau
# Processing Record 26 of Set 15 | campos do jordao
# Processing Record 27 of Set 15 | morant bay
# Processing Record 28 of Set 15 | codajas
# Processing Record 29 of Set 15 | charyshskoye
# Processing Record 30 of Set 15 | tomatlan
# Processing Record 31 of Set 15 | shingu
# Processing Record 32 of Set 15 | madimba
# Processing Record 33 of Set 15 | tautira
# Processing Record 34 of Set 15 | sikonge
# Processing Record 35 of Set 15 | taburi
# City not found.
# Processing Record 36 of Set 15 | balagansk
# Processing Record 37 of Set 15 | lenine
# Processing Record 38 of Set 15 | kysyl-syr
# Processing Record 39 of Set 15 | morros
# Processing Record 40 of Set 15 | sungaipenuh
# Processing Record 41 of Set 15 | moletai
# Processing Record 42 of Set 15 | houma
# Processing Record 43 of Set 15 | qandala
# Processing Record 44 of Set 15 | kandrian
# Processing Record 45 of Set 15 | lahaina
# Processing Record 46 of Set 15 | zhigansk
# Processing Record 47 of Set 15 | stillwater
# Processing Record 48 of Set 15 | jining
# Processing Record 49 of Set 15 | alugan
# Processing Record 50 of Set 15 | othaya
# Processing Record 1 of Set 16 | machachi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mananjary      MG -21.2167   48.3333     73.51        93          27
# 1      Hobart      AU -42.8794  147.3294     65.26        76          75
# 2   Egvekinot      RU  66.3167 -179.1667    -15.84        90          17
# 3      Lompoc      US  34.6391 -120.4579     78.94        64           0
# 4       Bluff      NZ -46.6000  168.3333     57.88        64         100
# 5  Oskarshamn      SE  57.2645   16.4484     37.80        75         100
# 6      Narsaq      GL  60.9167  -46.0500     19.62        96         100
# 7     Ushuaia      AR -54.8000  -68.3000     38.86        81          40
# 8  Bredasdorp      ZA -34.5322   20.0403     65.52        72          99
# 9      Albany      US  42.6001  -73.9662     22.26        55          26
#
#    Wind Speed Current Description
# 0        2.62    scattered clouds
# 1       11.50       broken clouds
# 2        5.84          few clouds
# 3        9.22           clear sky
# 4        3.74     overcast clouds
# 5       10.80     overcast clouds
# 6        6.80          light snow
# 7       26.46    scattered clouds
# 8        8.05     overcast clouds
# 9        1.01    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
